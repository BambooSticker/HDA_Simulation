# %%
from pyomo.environ import *
import os
import idaes
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import math
from idaes.core.util.math import safe_log
from idaes.core.util.model_statistics import degrees_of_freedom

# %%
# Parameters
component_list = ["benzene","toluene"]
phase_list = ["Liq", "Vap"]
pressure_crit_data = {"benzene": 48.9e5, "toluene": 41.0e5}
temperature_crit_data = {"benzene": 562.2, "toluene": 591.8}
kappa_data = {
            ("benzene", "benzene"): 0.0000,
            ("benzene", "toluene"): 0.0000,
            ("toluene", "benzene"): 0.0000,
            ("toluene", "toluene"): 0.0000,
        }
omega_data = {"benzene": 0.212, "toluene": 0.263}
R = 8.314

# %%
m = ConcreteModel()
# define external function for finding cubic roots
m.crl = ExternalFunction(
    library=os.path.join(idaes.bin_directory, "cubic_roots.so"),
    function="cubic_root_l_ext",
)
m.crh = ExternalFunction(
    library=os.path.join(idaes.bin_directory, "cubic_roots.so"),
    function="cubic_root_h_ext",
)

# %%
m.Comp = Set(initialize=component_list)
m.Phase = Set(initialize=phase_list)

m.flow_mol = Var(initialize=1.0,domain=NonNegativeReals)

m.mole_frac_comp = Var(m.Comp, bounds=(0, None), initialize=0.5)

m.flow_mol_phase = Var(m.Phase, initialize=0.5, domain=NonNegativeReals)

m.mole_frac_phase_comp = Var(m.Phase, m.Comp, initialize=0.5,bounds=(0, None))

def rule_total_mass_balance(m):
    return m.flow_mol_phase["Liq"] + m.flow_mol_phase["Vap"] == m.flow_mol
m.total_flow_balance = Constraint(rule=rule_total_mass_balance)

def rule_comp_mass_balance(m, c):
    return (
        m.flow_mol * m.mole_frac_comp[c]
        == m.flow_mol_phase["Liq"] * m.mole_frac_phase_comp["Liq", c]
        + m.flow_mol_phase["Vap"] * m.mole_frac_phase_comp["Vap", c]
    )
m.component_flow_balances = Constraint(m.Comp, rule=rule_comp_mass_balance)

def rule_mole_frac(m):
    return (
        sum(m.mole_frac_phase_comp["Liq", c] for c in m.Comp)
        - sum(m.mole_frac_phase_comp["Vap", c] for c in m.Comp)
        == 0
    )
m.sum_mole_frac = Constraint(rule=rule_mole_frac)

m.T = Var(initialize = 298.15)
m.P = Var(initialize = 101325)

m.Tc = Param(m.Comp,initialize = temperature_crit_data)
m.Pc = Param(m.Comp,initialize = pressure_crit_data)
m.kappa = Param(m.Comp, m.Comp, initialize = kappa_data)
m.omega = Param(m.Comp, initialize = omega_data)

# for SRK cEOS
m.OmegaA = Param(default=0.45724)
m.OmegaB = Param(default=0.07780)
m.EoS_u = Param(default=2)
m.EoS_w = Param(default=-1)
m.EoS_p = sqrt(m.EoS_u**2 - 4 * m.EoS_w)

def func_fw(m,j):
    return 0.48 + 1.574 * m.omega[j] - 0.176 * m.omega[j] ** 2
m.fw = Expression(m.Comp, rule = func_fw)

def func_a(m, j):
    return (m.OmegaA * ((R * m.Tc[j]) ** 2 / m.Pc[j])
        * ((1 + m.fw[j] * (1 - sqrt(m.T / m.Tc[j]))) #是不是平方？？？
            ** 2))
m.a = Expression(m.Comp,rule=func_a)

def func_b(m, j):
    return (
        m.OmegaB
        * R * m.Tc[j] / m.Pc[j]
    )
m.b = Expression(m.Comp,rule=func_b)

def rule_am(m, p):
    return sum(
    sum(
        m.mole_frac_phase_comp[p, i]
        * m.mole_frac_phase_comp[p, j]
        * sqrt(m.a[i] * m.a[j])
        * (1 - m.kappa[i, j])
        for j in m.Comp
    )
    for i in m.Comp
    )
m.am = Expression(m.Phase, rule=rule_am)

def rule_bm(m, p):
    return sum(m.mole_frac_phase_comp[p,i] * m.b[i] for i in m.Comp)
m.bm = Expression(m.Phase, rule=rule_bm)

def func_A(m,p):
    return m.am[p]*m.P/(R*m.T)**2
m.A = Expression(m.Phase, rule=func_A)

def func_B(m,p):
    return m.bm[p]*m.P/(R*m.T)
m.B = Expression(m.Phase, rule=func_B)

# %%
# 定义算根时的参数
m.cubic_coef_b = Var(m.Phase,initialize = 1)
def rule_cubic_coef_b(m,p):
    return -(1+m.B[p]-m.EoS_u*m.B[p])==m.cubic_coef_b[p]
m.eq_cubic_coef_b = Constraint(m.Phase, rule = rule_cubic_coef_b)

m.cubic_coef_c = Var(m.Phase,initialize = 1)
def rule_cubic_coef_c(m,p):
    return m.A[p]-m.EoS_u*m.B[p]-(m.EoS_u-m.EoS_w)*m.B[p]**2==m.cubic_coef_c[p]
m.eq_cubic_coef_c = Constraint(m.Phase, rule = rule_cubic_coef_c)

m.cubic_coef_d = Var(m.Phase,initialize = 1)
def rule_cubic_coef_d(m,p):
    return -m.A[p]*m.B[p]-m.EoS_w*m.B[p]**2-m.EoS_w*m.B[p]**3==m.cubic_coef_d[p]
m.eq_cubic_coef_d = Constraint(m.Phase, rule = rule_cubic_coef_d)

#z_liq, grad_liq, hes_liq = m.crl.evaluate_fgh(
#    args=(value(m.cubic_coef_b['Liq']), value(m.cubic_coef_c['Liq']), value(m.cubic_coef_d['Liq'])))
#z_vap, grad_vap, hes_vap = m.crh.evaluate_fgh(
#    args=(value(m.cubic_coef_b['Vap']), value(m.cubic_coef_c['Vap']), value(m.cubic_coef_d['Vap'])))
def evaluate_root(m,p):


    return m.crh.evaluate_fgh(args=(t["b"], t["c"], t["d"]), fgh=0)
m.external_expr = pyo.Expression(rule=evaluate_crh)

m.Z = Var(m.Phase, initialize = 1)
def rule_cubic_Z(m,p):
    return m.Z == m.crl.evaluate(args=(m.cubic_coef_b[p], m.cubic_coef_c[p], m.cubic_coef_d[p]))
m.cubic_z = Constraint(m.Phase, rule = rule_cubic_Z)
# Out:
# ERROR: Rule failed when generating expression for Constraint cubic_z with
# index Liq: ValueError: Invalid constraint expression. The constraint
# expression resolved to a trivial Boolean (False) instead of a Pyomo object.
# Please modify your rule to return Constraint.Infeasible instead of False.
#
#     Error thrown for Constraint 'cubic_z[Liq]'
# ERROR: Constructing component 'cubic_z' from data=None failed: ValueError:
# Invalid constraint expression. The constraint expression resolved to a trivial
# Boolean (False) instead of a Pyomo object. Please modify your rule to return
# Constraint.Infeasible instead of False.
#
#     Error thrown for Constraint 'cubic_z[Liq]'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 24
#      22 def rule_cubic_Z(m,p):
#      23     return m.Z == m.crl.evaluate(args=(m.cubic_coef_b[p], m.cubic_coef_c[p], m.cubic_coef_d[p]))
# ---> 24 m.cubic_z = Constraint(m.Phase, rule = rule_cubic_Z)
#
# File ~/anaconda3/envs/idaes-pse/lib/python3.9/site-packages/pyomo/core/base/block.py:580, in _BlockData.__setattr__(self, name, val)
#     575 if name not in self.__dict__:
#     576     if isinstance(val, Component):
#     577         #
#     578         # Pyomo components are added with the add_component method.
#     579         #
# --> 580         self.add_component(name, val)
#     581     else:
#     582         #
#     583         # Other Python objects are added with the standard __setattr__
#     584         # method.
#     585         #
#     586         super(_BlockData, self).__setattr__(name, val)
#
# File ~/anaconda3/envs/idaes-pse/lib/python3.9/site-packages/pyomo/core/base/block.py:1185, in _BlockData.add_component(self, name, val)
#    1177     logger.debug(
#    1178         "Constructing %s '%s' on %s from data=%s",
#    1179         val.__class__.__name__,
#    (...)
#    1182         str(data),
#    1183     )
#    1184 try:
# -> 1185     val.construct(data)
#    1186 except:
#    1187     err = sys.exc_info()[1]
#
# File ~/anaconda3/envs/idaes-pse/lib/python3.9/site-packages/pyomo/core/base/constraint.py:806, in Constraint.construct(self, data)
#     803     else:
#     804         # Bypass the index validation and create the member directly
#     805         for index in self.index_set():
# --> 806             self._setitem_when_not_present(index, rule(block, index))
#     807 except Exception:
#     808     err = sys.exc_info()[1]
#
# File ~/anaconda3/envs/idaes-pse/lib/python3.9/site-packages/pyomo/core/base/indexed_component.py:1128, in IndexedComponent._setitem_when_not_present(self, index, value)
#    1126 try:
#    1127     if value is not _NotSpecified:
# -> 1128         obj.set_value(value)
#    1129 except:
#    1130     self._data.pop(index, None)
#
# File ~/anaconda3/envs/idaes-pse/lib/python3.9/site-packages/pyomo/core/base/constraint.py:546, in _GeneralConstraintData.set_value(self, expr)
#     543     raise ValueError(_rule_returned_none_error % (self.name,))
#     545 elif expr.__class__ is bool:
# --> 546     raise ValueError(
#     547         "Invalid constraint expression. The constraint "
#     548         "expression resolved to a trivial Boolean (%s) "
#     549         "instead of a Pyomo object. Please modify your "
#     550         "rule to return Constraint.%s instead of %s."
#     551         "\n\nError thrown for Constraint '%s'"
#     552         % (expr, "Feasible" if expr else "Infeasible", expr, self.name)
#     553     )
#     555 else:
#     556     try:
#
# ValueError: Invalid constraint expression. The constraint expression resolved to a trivial Boolean (False) instead of a Pyomo object. Please modify your rule to return Constraint.Infeasible instead of False.
#
# Error thrown for Constraint 'cubic_z[Liq]'

# %%
help(m.crl)

# %%
# 用压缩因子计算相平衡
def rule_delta(m, p, i):
    # See pg. 145 in Properties of Gases and Liquids
    return (2 * sqrt(m.a[i]) / m.am[p]
        * sum(
            m.mole_frac_phase_comp[p, j]
            * sqrt(m.a[j])
            * (1 - m.kappa[i, j])
            for j in m.Comp
        )
    )
m.delta = Expression(m.Phase, m.Comp, rule=rule_delta)

def ln_fug_coeff_cubic(b, p, j):
    # See pg. 145 in Properties of Gases and Liquids
    return (
            b.b[j] / b.bm[p] * (b.Z[p] - 1) * (b.B[p] * b.EoS_p)
            - safe_log(b.Z[p] - b.B[p], eps=1e-6)
            * (m.B[p] * m.EoS_p)
            + b.A[p]
            * (b.b[j] / b.bm[p] - b.delta[p, j])
            * safe_log(
                (2 * b.Z[p] + b.B[p] * (b.EoS_u + b.EoS_p))
                / (2 * b.Z[p] + b.B[p] * (b.EoS_u - b.EoS_p)),
                eps=1e-6,
            )
        ) / (b.B[p] * b.EoS_p)
m.ln_fug_coeff = Expression(m.Phase, m.Comp, rule = ln_fug_coeff_cubic)

# %%
# 相平衡约束
def rule_VLE(m,c):
    return m.ln_fug_coeff['Vap',c] - m.ln_fug_coeff['Liq',c] ==0
m.rule_equilibrium = Constraint(m.Comp, rule = rule_VLE)

# %%
degrees_of_freedom(m)
# Out:
# 2

# %%
m.flow_mol.fix(100)
m.mole_frac_comp["benzene"].fix(0.5)
m.mole_frac_comp["toluene"].fix(0.5)
m.T.fix(370)
m.P.fix(101325)

# %%
solver = SolverFactory('ipopt')
solver.options['tol'] = 1e-3
results = solver.solve(m)

# %%
for p in m.Phase:
    for c in m.Comp:
        print(value(m.ln_fug_coeff[p,c]))
# Out:
# 12.209950169784841
# 11.7942959261937
# 12.20995016978484
# 11.794295926193705

# %%
expression_value

# %%
m.pprint()
# Out:
# 6 Set Declarations
#     Comp : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    2 : {'benzene', 'toluene'}
#     Phase : Size=1, Index=None, Ordered=Insertion
#         Key  : Dimen : Domain : Size : Members
#         None :     1 :    Any :    2 : {'Liq', 'Vap'}
#     delta_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain     : Size : Members
#         None :     2 : Phase*Comp :    4 : {('Liq', 'benzene'), ('Liq', 'toluene'), ('Vap', 'benzene'), ('Vap', 'toluene')}
#     kappa_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain    : Size : Members
#         None :     2 : Comp*Comp :    4 : {('benzene', 'benzene'), ('benzene', 'toluene'), ('toluene', 'benzene'), ('toluene', 'toluene')}
#     ln_fug_coeff_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain     : Size : Members
#         None :     2 : Phase*Comp :    4 : {('Liq', 'benzene'), ('Liq', 'toluene'), ('Vap', 'benzene'), ('Vap', 'toluene')}
#     mole_frac_phase_comp_index : Size=1, Index=None, Ordered=True
#         Key  : Dimen : Domain     : Size : Members
#         None :     2 : Phase*Comp :    4 : {('Liq', 'benzene'), ('Liq', 'toluene'), ('Vap', 'benzene'), ('Vap', 'toluene')}
#
# 8 Param Declarations
#     EoS_u : Size=1, Index=None, Domain=Any, Default=2, Mutable=False
#         Key : Value
#     EoS_w : Size=1, Index=None, Domain=Any, Default=-1, Mutable=False
#         Key : Value
#     OmegaA : Size=1, Index=None, Domain=Any, Default=0.45724, Mutable=False
#         Key : Value
#     OmegaB : Size=1, Index=None, Domain=Any, Default=0.0778, Mutable=False
#         Key : Value
#     Pc : Size=2, Index=Comp, Domain=Any, Default=None, Mutable=False
#         Key     : Value
#         benzene : 4890000.0
#         toluene : 4100000.0
#     Tc : Size=2, Index=Comp, Domain=Any, Default=None, Mutable=False
#         Key     : Value
#         benzene : 562.2
#         toluene : 591.8
#     kappa : Size=4, Index=kappa_index, Domain=Any, Default=None, Mutable=False
#         Key                    : Value
#         ('benzene', 'benzene') :   0.0
#         ('benzene', 'toluene') :   0.0
#         ('toluene', 'benzene') :   0.0
#         ('toluene', 'toluene') :   0.0
#     omega : Size=2, Index=Comp, Domain=Any, Default=None, Mutable=False
#         Key     : Value
#         benzene : 0.212
#         toluene : 0.263
#
# 10 Var Declarations
#     P : Size=1, Index=None
#         Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#         None :  None : 101325 :  None :  True :  True :  Reals
#     T : Size=1, Index=None
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :  None :   370 :  None :  True :  True :  Reals
#     Z : Size=2, Index=Phase
#         Key : Lower : Value               : Upper : Fixed : Stale : Domain
#         Liq :  None : -0.8539857122216965 :  None : False : False :  Reals
#         Vap :  None :  -0.853985712219687 :  None : False : False :  Reals
#     cubic_coef_b : Size=2, Index=Phase
#         Key : Lower : Value               : Upper : Fixed : Stale : Domain
#         Liq :  None : -0.9972376094760814 :  None : False : False :  Reals
#         Vap :  None : -0.9972376094760845 :  None : False : False :  Reals
#     cubic_coef_c : Size=2, Index=Phase
#         Key : Lower : Value               : Upper : Fixed : Stale : Domain
#         Liq :  None : 0.02901046891791421 :  None : False : False :  Reals
#         Vap :  None : 0.02901046891773217 :  None : False : False :  Reals
#     cubic_coef_d : Size=2, Index=Phase
#         Key : Lower : Value                  : Upper : Fixed : Stale : Domain
#         Liq :  None : -8.781120434690821e-05 :  None : False : False :  Reals
#         Vap :  None : -8.781120434629928e-05 :  None : False : False :  Reals
#     flow_mol : Size=1, Index=None
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :     0 :   100 :  None :  True :  True : NonNegativeReals
#     flow_mol_phase : Size=2, Index=Phase
#         Key : Lower : Value             : Upper : Fixed : Stale : Domain
#         Liq :     0 : 49.99999999965927 :  None : False : False : NonNegativeReals
#         Vap :     0 : 50.00000000034072 :  None : False : False : NonNegativeReals
#     mole_frac_comp : Size=2, Index=Comp
#         Key     : Lower : Value : Upper : Fixed : Stale : Domain
#         benzene :     0 :   0.5 :  None :  True :  True :  Reals
#         toluene :     0 :   0.5 :  None :  True :  True :  Reals
#     mole_frac_phase_comp : Size=4, Index=mole_frac_phase_comp_index
#         Key                : Lower : Value               : Upper : Fixed : Stale : Domain
#         ('Liq', 'benzene') :     0 :  0.5000000000153086 :  None : False : False :  Reals
#         ('Liq', 'toluene') :     0 : 0.49999999998830535 :  None : False : False :  Reals
#         ('Vap', 'benzene') :     0 :  0.4999999999846914 :  None : False : False :  Reals
#         ('Vap', 'toluene') :     0 :  0.5000000000116948 :  None : False : False :  Reals
#
# 9 Expression Declarations
#     A : Size=2, Index=Phase
#         Key : Expression
#         Liq : (mole_frac_phase_comp[Liq,benzene]*mole_frac_phase_comp[Liq,benzene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Liq,benzene]*mole_frac_phase_comp[Liq,toluene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)) + mole_frac_phase_comp[Liq,toluene]*mole_frac_phase_comp[Liq,benzene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Liq,toluene]*mole_frac_phase_comp[Liq,toluene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)))*P/(8.314*T)**2
#         Vap : (mole_frac_phase_comp[Vap,benzene]*mole_frac_phase_comp[Vap,benzene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Vap,benzene]*mole_frac_phase_comp[Vap,toluene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)) + mole_frac_phase_comp[Vap,toluene]*mole_frac_phase_comp[Vap,benzene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Vap,toluene]*mole_frac_phase_comp[Vap,toluene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)))*P/(8.314*T)**2
#     B : Size=2, Index=Phase
#         Key : Expression
#         Liq : (mole_frac_phase_comp[Liq,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Liq,toluene]*9.336427330731707e-05)*P/(8.314*T)
#         Vap : (mole_frac_phase_comp[Vap,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Vap,toluene]*9.336427330731707e-05)*P/(8.314*T)
#     a : Size=2, Index=Comp
#         Key     : Expression
#         benzene : 2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2
#         toluene : 2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2
#     am : Size=2, Index=Phase
#         Key : Expression
#         Liq : mole_frac_phase_comp[Liq,benzene]*mole_frac_phase_comp[Liq,benzene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Liq,benzene]*mole_frac_phase_comp[Liq,toluene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)) + mole_frac_phase_comp[Liq,toluene]*mole_frac_phase_comp[Liq,benzene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Liq,toluene]*mole_frac_phase_comp[Liq,toluene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2))
#         Vap : mole_frac_phase_comp[Vap,benzene]*mole_frac_phase_comp[Vap,benzene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Vap,benzene]*mole_frac_phase_comp[Vap,toluene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)) + mole_frac_phase_comp[Vap,toluene]*mole_frac_phase_comp[Vap,benzene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Vap,toluene]*mole_frac_phase_comp[Vap,toluene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2))
#     b : Size=2, Index=Comp
#         Key     : Expression
#         benzene : 7.436551661349693e-05
#         toluene : 9.336427330731707e-05
#     bm : Size=2, Index=Phase
#         Key : Expression
#         Liq : mole_frac_phase_comp[Liq,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Liq,toluene]*9.336427330731707e-05
#         Vap : mole_frac_phase_comp[Vap,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Vap,toluene]*9.336427330731707e-05
#     delta : Size=4, Index=delta_index
#         Key                : Expression
#         ('Liq', 'benzene') : 2*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2))/(mole_frac_phase_comp[Liq,benzene]*mole_frac_phase_comp[Liq,benzene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Liq,benzene]*mole_frac_phase_comp[Liq,toluene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)) + mole_frac_phase_comp[Liq,toluene]*mole_frac_phase_comp[Liq,benzene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Liq,toluene]*mole_frac_phase_comp[Liq,toluene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)))*(mole_frac_phase_comp[Liq,benzene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Liq,toluene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)))
#         ('Liq', 'toluene') : 2*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2))/(mole_frac_phase_comp[Liq,benzene]*mole_frac_phase_comp[Liq,benzene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Liq,benzene]*mole_frac_phase_comp[Liq,toluene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)) + mole_frac_phase_comp[Liq,toluene]*mole_frac_phase_comp[Liq,benzene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Liq,toluene]*mole_frac_phase_comp[Liq,toluene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)))*(mole_frac_phase_comp[Liq,benzene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Liq,toluene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)))
#         ('Vap', 'benzene') : 2*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2))/(mole_frac_phase_comp[Vap,benzene]*mole_frac_phase_comp[Vap,benzene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Vap,benzene]*mole_frac_phase_comp[Vap,toluene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)) + mole_frac_phase_comp[Vap,toluene]*mole_frac_phase_comp[Vap,benzene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Vap,toluene]*mole_frac_phase_comp[Vap,toluene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)))*(mole_frac_phase_comp[Vap,benzene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Vap,toluene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)))
#         ('Vap', 'toluene') : 2*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2))/(mole_frac_phase_comp[Vap,benzene]*mole_frac_phase_comp[Vap,benzene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Vap,benzene]*mole_frac_phase_comp[Vap,toluene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)) + mole_frac_phase_comp[Vap,toluene]*mole_frac_phase_comp[Vap,benzene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Vap,toluene]*mole_frac_phase_comp[Vap,toluene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)))*(mole_frac_phase_comp[Vap,benzene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Vap,toluene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)))
#     fw : Size=2, Index=Comp
#         Key     : Expression
#         benzene : 0.805777856
#         toluene : 0.881788256
#     ln_fug_coeff : Size=4, Index=ln_fug_coeff_index
#         Key                : Expression
#         ('Liq', 'benzene') : (7.436551661349693e-05/(mole_frac_phase_comp[Liq,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Liq,toluene]*9.336427330731707e-05)*(Z[Liq] - 1)*(((mole_frac_phase_comp[Liq,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Liq,toluene]*9.336427330731707e-05)*P/(8.314*T))*2.8284271247461903) - log(0.5*(Z[Liq] - ((mole_frac_phase_comp[Liq,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Liq,toluene]*9.336427330731707e-05)*P/(8.314*T)) + 1e-06 + ((Z[Liq] - ((mole_frac_phase_comp[Liq,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Liq,toluene]*9.336427330731707e-05)*P/(8.314*T)) - 1e-06)**2 + 1e-12)**0.5))*(((mole_frac_phase_comp[Liq,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Liq,toluene]*9.336427330731707e-05)*P/(8.314*T))*2.8284271247461903) + ((mole_frac_phase_comp[Liq,benzene]*mole_frac_phase_comp[Liq,benzene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Liq,benzene]*mole_frac_phase_comp[Liq,toluene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2
benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Vap,toluene]*9.336427330731707e-05)*P/(8.314*T))*-0.8284271247461903) + 1e-06 + (((2*Z[Vap] + ((mole_frac_phase_comp[Vap,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Vap,toluene]*9.336427330731707e-05)*P/(8.314*T))*4.82842712474619)/(2*Z[Vap] + ((mole_frac_phase_comp[Vap,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Vap,toluene]*9.336427330731707e-05)*P/(8.314*T))*-0.8284271247461903) - 1e-06)**2 + 1e-12)**0.5)))/(((mole_frac_phase_comp[Vap,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Vap,toluene]*9.336427330731707e-05)*P/(8.314*T))*2.8284271247461903)
#
# 6 Constraint Declarations
#     component_flow_balances : Size=2, Index=Comp, Active=True
#         Key     : Lower : Body                                                                                                                                               : Upper : Active
#         benzene :   0.0 : flow_mol*mole_frac_comp[benzene] - (flow_mol_phase[Liq]*mole_frac_phase_comp[Liq,benzene] + flow_mol_phase[Vap]*mole_frac_phase_comp[Vap,benzene]) :   0.0 :   True
#         toluene :   0.0 : flow_mol*mole_frac_comp[toluene] - (flow_mol_phase[Liq]*mole_frac_phase_comp[Liq,toluene] + flow_mol_phase[Vap]*mole_frac_phase_comp[Vap,toluene]) :   0.0 :   True
#     eq_cubic_coef_b : Size=2, Index=Phase, Active=True
#         Key : Lower : Body                                                                                                                                                                                                                                                                                                : Upper : Active
#         Liq :   0.0 : - (1 + ((mole_frac_phase_comp[Liq,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Liq,toluene]*9.336427330731707e-05)*P/(8.314*T)) - 2*((mole_frac_phase_comp[Liq,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Liq,toluene]*9.336427330731707e-05)*P/(8.314*T))) - cubic_coef_b[Liq] :   0.0 :   True
#         Vap :   0.0 : - (1 + ((mole_frac_phase_comp[Vap,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Vap,toluene]*9.336427330731707e-05)*P/(8.314*T)) - 2*((mole_frac_phase_comp[Vap,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Vap,toluene]*9.336427330731707e-05)*P/(8.314*T))) - cubic_coef_b[Vap] :   0.0 :   True
#     eq_cubic_coef_c : Size=2, Index=Phase, Active=True
#         Key : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            : Upper : Active
#         Liq :   0.0 : ((mole_frac_phase_comp[Liq,benzene]*mole_frac_phase_comp[Liq,benzene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Liq,benzene]*mole_frac_phase_comp[Liq,toluene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)) + mole_frac_phase_comp[Liq,toluene]*mole_frac_phase_comp[Liq,benzene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Liq,toluene]*mole_frac_phase_comp[Liq,toluene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)))*P/(8.314*T)**2) - 2*((mole_frac_phase_comp[Liq,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Liq,toluene]*9.336427330731707e-05)*P/(8.314*T)) - 3*((mole_frac_phase_comp[Liq,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Liq,toluene]*9.336427330731707e-05)*P/(8.314*T))**2 - cubic_coef_c[Liq] :   0.0 :   True
#         Vap :   0.0 : ((mole_frac_phase_comp[Vap,benzene]*mole_frac_phase_comp[Vap,benzene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Vap,benzene]*mole_frac_phase_comp[Vap,toluene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)) + mole_frac_phase_comp[Vap,toluene]*mole_frac_phase_comp[Vap,benzene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Vap,toluene]*mole_frac_phase_comp[Vap,toluene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)))*P/(8.314*T)**2) - 2*((mole_frac_phase_comp[Vap,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Vap,toluene]*9.336427330731707e-05)*P/(8.314*T)) - 3*((mole_frac_phase_comp[Vap,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Vap,toluene]*9.336427330731707e-05)*P/(8.314*T))**2 - cubic_coef_c[Vap] :   0.0 :   True
#     eq_cubic_coef_d : Size=2, Index=Phase, Active=True
#         Key : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               : Upper : Active
#         Liq :   0.0 : - ((mole_frac_phase_comp[Liq,benzene]*mole_frac_phase_comp[Liq,benzene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Liq,benzene]*mole_frac_phase_comp[Liq,toluene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)) + mole_frac_phase_comp[Liq,toluene]*mole_frac_phase_comp[Liq,benzene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Liq,toluene]*mole_frac_phase_comp[Liq,toluene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)))*P/(8.314*T)**2)*((mole_frac_phase_comp[Liq,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Liq,toluene]*9.336427330731707e-05)*P/(8.314*T)) + ((mole_frac_phase_comp[Liq,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Liq,toluene]*9.336427330731707e-05)*P/(8.314*T))**2 + ((mole_frac_phase_comp[Liq,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Liq,toluene]*9.336427330731707e-05)*P/(8.314*T))**3 - cubic_coef_d[Liq] :   0.0 :   True
#         Vap :   0.0 : - ((mole_frac_phase_comp[Vap,benzene]*mole_frac_phase_comp[Vap,benzene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Vap,benzene]*mole_frac_phase_comp[Vap,toluene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)) + mole_frac_phase_comp[Vap,toluene]*mole_frac_phase_comp[Vap,benzene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Vap,toluene]*mole_frac_phase_comp[Vap,toluene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)))*P/(8.314*T)**2)*((mole_frac_phase_comp[Vap,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Vap,toluene]*9.336427330731707e-05)*P/(8.314*T)) + ((mole_frac_phase_comp[Vap,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Vap,toluene]*9.336427330731707e-05)*P/(8.314*T))**2 + ((mole_frac_phase_comp[Vap,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Vap,toluene]*9.336427330731707e-05)*P/(8.314*T))**3 - cubic_coef_d[Vap] :   0.0 :   True
#     rule_equilibrium : Size=2, Index=Comp, Active=True
#         Key     : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
#         benzene :   0.0 : ((7.436551661349693e-05/(mole_frac_phase_comp[Vap,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Vap,toluene]*9.336427330731707e-05)*(Z[Vap] - 1)*(((mole_frac_phase_comp[Vap,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Vap,toluene]*9.336427330731707e-05)*P/(8.314*T))*2.8284271247461903) - log(0.5*(Z[Vap] - ((mole_frac_phase_comp[Vap,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Vap,toluene]*9.336427330731707e-05)*P/(8.314*T)) + 1e-06 + ((Z[Vap] - ((mole_frac_phase_comp[Vap,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Vap,toluene]*9.336427330731707e-05)*P/(8.314*T)) - 1e-06)**2 + 1e-12)**0.5))*(((mole_frac_phase_comp[Vap,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[
.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Vap,toluene]*mole_frac_phase_comp[Vap,toluene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)))*P/(8.314*T)**2)*(9.336427330731707e-05/(mole_frac_phase_comp[Vap,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Vap,toluene]*9.336427330731707e-05) - (2*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2))/(mole_frac_phase_comp[Vap,benzene]*mole_frac_phase_comp[Vap,benzene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Vap,benzene]*mole_frac_phase_comp[Vap,toluene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)) + mole_frac_phase_comp[Vap,toluene]*mole_frac_phase_comp[Vap,benzene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Vap,toluene]*mole_frac_phase_comp[Vap,toluene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)*(2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)))*(mole_frac_phase_comp[Vap,benzene]*sqrt((2.0428528265488697*(1 + 0.805777856*(1 - sqrt(0.0017787264318747775*T)))**2)) + mole_frac_phase_comp[Vap,toluene]*sqrt((2.6997920947310403*(1 + 0.881788256*(1 - sqrt(0.001689760054072322*T)))**2)))))*log(0.5*((2*Z[Vap] + ((mole_frac_phase_comp[Vap,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Vap,toluene]*9.336427330731707e-05)*P/(8.314*T))*4.82842712474619)/(2*Z[Vap] + ((mole_frac_phase_comp[Vap,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Vap,toluene]*9.336427330731707e-05)*P/(8.314*T))*-0.8284271247461903) + 1e-06 + (((2*Z[Vap] + ((mole_frac_phase_comp[Vap,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Vap,toluene]*9.336427330731707e-05)*P/(8.314*T))*4.82842712474619)/(2*Z[Vap] + ((mole_frac_phase_comp[Vap,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Vap,toluene]*9.336427330731707e-05)*P/(8.314*T))*-0.8284271247461903) - 1e-06)**2 + 1e-12)**0.5)))/(((mole_frac_phase_comp[Vap,benzene]*7.436551661349693e-05 + mole_frac_phase_comp[Vap,toluene]*9.336427330731707e-05)*P/(8.314*T))*2.8284271247461903)) - ((9 ...
#     total_flow_balance : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                                 : Upper : Active
#         None :   0.0 : flow_mol_phase[Liq] + flow_mol_phase[Vap] - flow_mol :   0.0 :   True
#
# 2 ExternalFunction Declarations
#     crh : function=cubic_root_h_ext, library=/Users/lizhe/.idaes/bin/cubic_roots.dylib, units=None, arg_units=None
#     crl : function=cubic_root_l_ext, library=/Users/lizhe/.idaes/bin/cubic_roots.dylib, units=None, arg_units=None
#
# 41 Declarations: crl crh Comp Phase flow_mol mole_frac_comp flow_mol_phase mole_frac_phase_comp_index mole_frac_phase_comp total_flow_balance component_flow_balances T P Tc Pc kappa_index kappa omega OmegaA OmegaB EoS_u EoS_w fw a b am bm A B cubic_coef_b eq_cubic_coef_b cubic_coef_c eq_cubic_coef_c cubic_coef_d eq_cubic_coef_d Z delta_index delta ln_fug_coeff_index ln_fug_coeff rule_equilibrium

# %%
m.flow_mol_phase.pprint()
# Out:
# flow_mol_phase : Size=2, Index=Phase
#     Key : Lower : Value             : Upper : Fixed : Stale : Domain
#     Liq :     0 : 49.99999999965927 :  None : False : False : NonNegativeReals
#     Vap :     0 : 50.00000000034072 :  None : False : False : NonNegativeReals
