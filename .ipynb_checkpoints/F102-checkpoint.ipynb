# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pyomo.environ import *
from idaes.core.util.misc import extract_data
import pyomo.environ as pyo
from pyomo.util.calc_var_value import calculate_variable_from_constraint
from State_Block import Create_State_Block
from idaes.core.util.model_statistics import degrees_of_freedom
from Unit_Model import F101_creater
from Method import Initialize

# %%
# Create a concrete model
m = ConcreteModel()
# Define a set for components
m.Phase = Set(initialize = ['Liq','Vap'])
m.Comp = Set(initialize = ['benzene','toluene','methane','hydrogen'])

# %%
m.F101 = F101_creater(m)

# %%
# 各组分进料
m.F101.inlet.flow['Liq','benzene'].fix(1e-8)
m.F101.inlet.flow['Liq','toluene'].fix(1e-8)
m.F101.inlet.flow['Liq','methane'].fix(1e-8)
m.F101.inlet.flow['Liq','hydrogen'].fix(1e-8)
m.F101.inlet.flow['Vap','benzene'].fix(0.35374)
m.F101.inlet.flow['Vap','toluene'].fix(0.078129)
m.F101.inlet.flow['Vap','methane'].fix(1.2721)
m.F101.inlet.flow['Vap','hydrogen'].fix(0.32821)

# 温度压力
m.F101.inlet.P.fix(350000)
m.F101.inlet.T.fix(771.85)

m.F101.outlet.P.fix(350000)
m.F101.outlet.T.fix(325)

# %%
Initialize(m.F101)

# %%
# 模型求解
solver = pyo.SolverFactory('ipopt')
solver.options['tol'] = 1e-2
results = solver.solve(m,tee=True)
# Out:
# Ipopt 3.13.2: tol=0.01
#
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
#
# This version of Ipopt was compiled from source code available at
#     https://github.com/IDAES/Ipopt as part of the Institute for the Design of
#     Advanced Energy Systems Process Systems Engineering Framework (IDAES PSE
#     Framework) Copyright (c) 2018-2019. See https://github.com/IDAES/idaes-pse.
#
# This version of Ipopt was compiled using HSL, a collection of Fortran codes
#     for large-scale scientific computation.  All technical papers, sales and
#     publicity material resulting from use of the HSL codes within IPOPT must
#     contain the following acknowledgement:
#         HSL, a collection of Fortran codes for large-scale scientific
#         computation. See http://www.hsl.rl.ac.uk.
# ******************************************************************************
#
# This is Ipopt version 3.13.2, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:       89
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       92
#
# Total number of variables............................:       29
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:       12
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       29
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 7.00e+08 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  0.0000000e+00 3.63e+08 1.06e+11  -1.0 4.17e+06    -  1.17e-01 4.82e-01h  1
#    2  0.0000000e+00 3.15e+08 7.82e+10  -1.0 2.76e+06    -  1.43e-01 1.31e-01h  1
#    3  0.0000000e+00 2.20e+08 4.16e+11  -1.0 4.43e+06    -  6.33e-03 3.02e-01h  1
#    4  0.0000000e+00 1.70e+08 3.82e+11  -1.0 9.52e+06    -  2.27e-02 2.28e-01h  1
#    5  0.0000000e+00 9.32e+07 2.20e+12  -1.0 1.61e+07    -  2.11e-01 4.51e-01h  1
#    6  0.0000000e+00 6.84e+07 6.85e+11  -1.0 3.15e+07    -  2.67e-01 2.66e-01h  1
#    7  0.0000000e+00 3.53e+05 1.27e+13  -1.0 4.34e+07    -  8.68e-02 9.96e-01h  1
#    8  0.0000000e+00 1.19e+05 1.57e+12  -1.0 6.45e+07    -  7.15e-02 5.18e-01h  1
#    9  0.0000000e+00 3.46e+04 1.64e+12  -1.0 5.77e+07    -  6.99e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  0.0000000e+00 6.21e+03 2.43e+11  -1.0 1.99e+07    -  9.44e-01 1.00e+00h  1
#   11  0.0000000e+00 4.37e+01 1.85e+09  -1.0 1.34e+06    -  9.90e-01 1.00e+00h  1
#   12  0.0000000e+00 1.36e-03 5.56e+04  -1.0 5.14e+03    -  9.90e-01 1.00e+00h  1
#   13  0.0000000e+00 8.73e-11 1.31e-02  -1.0 7.54e-02    -  9.90e-01 1.00e+00h  1
#
# Number of Iterations....: 13
#
#                                    (scaled)                 (unscaled)
# Objective...............:   0.0000000000000000e+00    0.0000000000000000e+00
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   1.3304608208792551e-13    8.7311491370201111e-11
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   1.3304608208792551e-13    8.7311491370201111e-11
#
#
# Number of objective function evaluations             = 14
# Number of objective gradient evaluations             = 14
# Number of equality constraint evaluations            = 14
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 14
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 13
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.003
# Total CPU secs in NLP function evaluations           =      0.000
#
# EXIT: Optimal Solution Found.

# %%
m.F101.pprint()
# Out:
# F101 : Size=1, Index=None, Active=True
#     7 Set Declarations
#         Comp : Size=1, Index=None, Ordered=Insertion
#             Key  : Dimen : Domain : Size : Members
#             None :     1 :    Any :    4 : {'benzene', 'toluene', 'methane', 'hydrogen'}
#         Phase : Size=1, Index=None, Ordered=Insertion
#             Key  : Dimen : Domain : Size : Members
#             None :     1 :    Any :    2 : {'Liq', 'Vap'}
#         cp_ig_1_index : Size=1, Index=None, Ordered=True
#             Key  : Dimen : Domain               : Size : Members
#             None :     2 : F101.Phase*F101.Comp :    8 : {('Liq', 'benzene'), ('Liq', 'toluene'), ('Liq', 'methane'), ('Liq', 'hydrogen'), ('Vap', 'benzene'), ('Vap', 'toluene'), ('Vap', 'methane'), ('Vap', 'hydrogen')}
#         cp_ig_2_index : Size=1, Index=None, Ordered=True
#             Key  : Dimen : Domain               : Size : Members
#             None :     2 : F101.Phase*F101.Comp :    8 : {('Liq', 'benzene'), ('Liq', 'toluene'), ('Liq', 'methane'), ('Liq', 'hydrogen'), ('Vap', 'benzene'), ('Vap', 'toluene'), ('Vap', 'methane'), ('Vap', 'hydrogen')}
#         cp_ig_3_index : Size=1, Index=None, Ordered=True
#             Key  : Dimen : Domain               : Size : Members
#             None :     2 : F101.Phase*F101.Comp :    8 : {('Liq', 'benzene'), ('Liq', 'toluene'), ('Liq', 'methane'), ('Liq', 'hydrogen'), ('Vap', 'benzene'), ('Vap', 'toluene'), ('Vap', 'methane'), ('Vap', 'hydrogen')}
#         cp_ig_4_index : Size=1, Index=None, Ordered=True
#             Key  : Dimen : Domain               : Size : Members
#             None :     2 : F101.Phase*F101.Comp :    8 : {('Liq', 'benzene'), ('Liq', 'toluene'), ('Liq', 'methane'), ('Liq', 'hydrogen'), ('Vap', 'benzene'), ('Vap', 'toluene'), ('Vap', 'methane'), ('Vap', 'hydrogen')}
#         cp_ig_5_index : Size=1, Index=None, Ordered=True
#             Key  : Dimen : Domain               : Size : Members
#             None :     2 : F101.Phase*F101.Comp :    8 : {('Liq', 'benzene'), ('Liq', 'toluene'), ('Liq', 'methane'), ('Liq', 'hydrogen'), ('Vap', 'benzene'), ('Vap', 'toluene'), ('Vap', 'methane'), ('Vap', 'hydrogen')}
#
#     14 Param Declarations
#         cp_ig_1 : Parameter 1 to compute Cp_comp
#             Size=8, Index=F101.cp_ig_1_index, Domain=Any, Default=None, Mutable=False
#             Key                 : Value
#              ('Liq', 'benzene') : 129000.0
#             ('Liq', 'hydrogen') :    1e-08
#              ('Liq', 'methane') :    1e-08
#              ('Liq', 'toluene') : 140000.0
#              ('Vap', 'benzene') :   -33.92
#             ('Vap', 'hydrogen') :    27.14
#              ('Vap', 'methane') :    19.25
#              ('Vap', 'toluene') :   -24.35
#         cp_ig_2 : Parameter 2 to compute Cp_comp
#             Size=8, Index=F101.cp_ig_2_index, Domain=Any, Default=None, Mutable=False
#             Key                 : Value
#              ('Liq', 'benzene') :   -170.0
#             ('Liq', 'hydrogen') :    1e-08
#              ('Liq', 'methane') :    1e-08
#              ('Liq', 'toluene') :   -152.0
#              ('Vap', 'benzene') :   0.4739
#             ('Vap', 'hydrogen') : 0.009274
#              ('Vap', 'methane') :  0.05213
#              ('Vap', 'toluene') :   0.5125
#         cp_ig_3 : Parameter 3 to compute Cp_comp
#             Size=8, Index=F101.cp_ig_3_index, Domain=Any, Default=None, Mutable=False
#             Key                 : Value
#              ('Liq', 'benzene') :      0.648
#             ('Liq', 'hydrogen') :      1e-08
#              ('Liq', 'methane') :      1e-08
#              ('Liq', 'toluene') :      0.695
#              ('Vap', 'benzene') : -0.0003017
#             ('Vap', 'hydrogen') : -1.381e-05
#              ('Vap', 'methane') :  1.197e-05
#              ('Vap', 'toluene') : -0.0002765
#         cp_ig_4 : Parameter 4 to compute Cp_comp
#             Size=8, Index=F101.cp_ig_4_index, Domain=Any, Default=None, Mutable=False
#             Key                 : Value
#              ('Liq', 'benzene') :          0
#             ('Liq', 'hydrogen') :      1e-08
#              ('Liq', 'methane') :      1e-08
#              ('Liq', 'toluene') :          0
#              ('Vap', 'benzene') :   7.13e-08
#             ('Vap', 'hydrogen') :  7.645e-09
#              ('Vap', 'methane') : -1.132e-08
#              ('Vap', 'toluene') :  4.911e-08
#         cp_ig_5 : Parameter 5 to compute Cp_comp
#             Size=8, Index=F101.cp_ig_5_index, Domain=Any, Default=None, Mutable=False
#             Key                 : Value
#              ('Liq', 'benzene') :     0
#             ('Liq', 'hydrogen') :     0
#              ('Liq', 'methane') :     0
#              ('Liq', 'toluene') :     0
#              ('Vap', 'benzene') :     0
#             ('Vap', 'hydrogen') :     0
#              ('Vap', 'methane') :     0
#              ('Vap', 'toluene') :     0
#         dh_vap : heat of vaporization
#             Size=4, Index=F101.Comp, Domain=Any, Default=None, Mutable=False
#             Key      : Value
#              benzene : 33870.0
#             hydrogen :       0
#              methane :       0
#              toluene : 38262.0
#         eps_1 : Smoothing parameter for T1
#             Size=1, Index=None, Domain=Any, Default=0.01, Mutable=True
#             Key  : Value
#             None :  0.01
#         eps_2 : Smoothing parameter for Teq
#             Size=1, Index=None, Domain=Any, Default=0.0005, Mutable=True
#             Key  : Value
#             None : 0.0005
#         pressure_ref : Reference pressure
#             Size=1, Index=None, Domain=Any, Default=101325, Mutable=True
#             Key : Value
#         pressure_sat_coeff_A : Parameter A to compute saturated pressure
#             Size=4, Index=F101.Comp, Domain=Any, Default=None, Mutable=False
#             Key      : Value
#              benzene : 4.202
#             hydrogen : 3.543
#              methane :  3.99
#              toluene : 4.216
#         pressure_sat_coeff_B : Parameter B to compute saturated pressure
#             Size=4, Index=F101.Comp, Domain=Any, Default=None, Mutable=False
#             Key      : Value
#              benzene :  1322
#             hydrogen :  99.4
#              methane : 443.0
#              toluene :  1435
#         pressure_sat_coeff_C : Parameter C to compute saturated pressure
#             Size=4, Index=F101.Comp, Domain=Any, Default=None, Mutable=False
#             Key      : Value
#              benzene : -38.56
#             hydrogen :  7.726
#              methane :  -0.49
#              toluene : -43.33
#         temperature_bubble : Bubble point temperature
#             Size=1, Index=None, Domain=Any, Default=None, Mutable=False
#             Key  : Value
#             None :    50
#         temperature_ref : Reference temperature
#             Size=1, Index=None, Domain=Any, Default=298.15, Mutable=True
#             Key  : Value
#             None : 298.15
#
#     5 Var Declarations
#         Q : Size=1, Index=None
#             Key  : Lower : Value              : Upper : Fixed : Stale : Domain
#             None :  None : -70386.76884515079 :  None : False : False :  Reals
#         _t1 : Intermediate temperature for calculating Teq
#             Size=1, Index=None
#             Key  : Lower : Value             : Upper : Fixed : Stale : Domain
#             None :  None : 325.0000000909091 :  None :  True :  True :  Reals
#         _teq : Temperature for calculating phase equilibrium
#             Size=1, Index=None
#             Key  : Lower : Value             : Upper : Fixed : Stale : Domain
#             None :  None : 325.0000000885963 :  None :  True :  True :  Reals
#         pressure_sat : Vapor pressure
#             Size=4, Index=F101.Comp
#             Key      : Lower : Value              : Upper         : Fixed : Stale : Domain
#              benzene :   100 :  38612.04516384541 : 10000000000.0 : False : False :  Reals
#             hydrogen :   100 : 175491339.11643314 : 10000000000.0 : False : False :  Reals
#              methane :   100 :  42156531.71408694 : 10000000000.0 : False : False :  Reals
#              toluene :   100 : 13224.697191130294 : 10000000000.0 : False : False :  Reals
#         temperature_dew : Dew point temperature
#             Size=1, Index=None
#             Key  : Lower : Value             : Upper : Fixed : Stale : Domain
#             None :   100 : 352.0230817856655 :   500 :  True :  True :  Reals
#
#     1 Expression Declarations
#         _p_sat_dewT : Size=4, Index=F101.Comp
#             Key      : Expression
#              benzene : 100000.0*10**(4.202 - 1322/(F101.temperature_dew - 38.56))
#             hydrogen : 100000.0*10**(3.543 - 99.4/(F101.temperature_dew + 7.726))
#              methane : 100000.0*10**(3.99 - 443.0/(F101.temperature_dew - 0.49))
#              toluene : 100000.0*10**(4.216 - 1435/(F101.temperature_dew - 43.33))
#
#     8 Constraint Declarations
#         eq_phase_equilibrium : Size=4, Index=F101.Comp, Active=True
#             Key      : Lower : Body                                                                                                                                                                                                                                                                                                                                                                            : Upper : Active
#              benzene :   0.0 :    (F101.outlet.flow[Liq,benzene]/(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen]))*F101.pressure_sat[benzene] - (F101.outlet.flow[Vap,benzene]/(F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen]))*F101.outlet.P :   0.0 :   True
#             hydrogen :   0.0 : (F101.outlet.flow[Liq,hydrogen]/(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen]))*F101.pressure_sat[hydrogen] - (F101.outlet.flow[Vap,hydrogen]/(F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen]))*F101.outlet.P :   0.0 :   True
#              methane :   0.0 :    (F101.outlet.flow[Liq,methane]/(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen]))*F101.pressure_sat[methane] - (F101.outlet.flow[Vap,methane]/(F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen]))*F101.outlet.P :   0.0 :   True
#              toluene :   0.0 :    (F101.outlet.flow[Liq,toluene]/(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen]))*F101.pressure_sat[toluene] - (F101.outlet.flow[Vap,toluene]/(F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen]))*F101.outlet.P :   0.0 :   True
#         eq_pressure_sat : Size=4, Index=F101.Comp, Active=True
#             Key      : Lower   : Body                                                                   : Upper   : Active
#              benzene : -1322.0 :  (log10(1e-05*F101.pressure_sat[benzene]) - 4.202)*(F101._teq - 38.56) : -1322.0 :   True
#             hydrogen :   -99.4 : (log10(1e-05*F101.pressure_sat[hydrogen]) - 3.543)*(F101._teq + 7.726) :   -99.4 :   True
#              methane :  -443.0 :    (log10(1e-05*F101.pressure_sat[methane]) - 3.99)*(F101._teq - 0.49) :  -443.0 :   True
#              toluene : -1435.0 :  (log10(1e-05*F101.pressure_sat[toluene]) - 4.216)*(F101._teq - 43.33) : -1435.0 :   True
#         rule_energy_balance : Size=1, Index=None, Active=True
#             Key  : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   : Upper : Active
#             None :   0.0 : ((F101.inlet.enth_mol_phase_comp[Liq,benzene]*(F101.inlet.flow[Liq,benzene]/(F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Liq,methane] + F101.inlet.flow[Liq,hydrogen])) + F101.inlet.enth_mol_phase_comp[Liq,toluene]*(F101.inlet.flow[Liq,toluene]/(F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Liq,methane] + F101.inlet.flow[Liq,hydrogen])) + F101.inlet.enth_mol_phase_comp[Liq,methane]*(F101.inlet.flow[Liq,methane]/(F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Liq,methane] + F101.inlet.flow[Liq,hydrogen])) + F101.inlet.enth_mol_phase_comp[Liq,hydrogen]*(F101.inlet.flow[Liq,hydrogen]/(F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Liq,methane] + F101.inlet.flow[Liq,hydrogen])))*(F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Liq,methane] + F101.inlet.flow[Liq,hydrogen]) + (F101.inlet.enth_mol_phase_comp[Vap,benzene]*(F101.inlet.flow[Vap,benzene]/(F101.inlet.flow[Vap,benzene] + F101.inlet.flow[Vap,toluene] + F101.inlet.flow[Vap,methane] + F101.inlet.flow[Vap,hydrogen])) + F101.inlet.enth_mol_phase_comp[Vap,toluene]*(F101.inlet.flow[Vap,toluene]/(F101.inlet.flow[Vap,benzene] + F101.inlet.flow[Vap,toluene] + F101.inlet.flow[Vap,methane] + F101.inlet.flow[Vap,hydrogen])) + F101.inlet.enth_mol_phase_comp[Vap,methane]*(F101.inlet.flow[Vap,methane]/(F101.inlet.flow[Vap,benzene] + F101.inlet.flow[Vap,toluene] + F101.inlet.flow[Vap,methane] + F101.inlet.flow[Vap,hydrogen])) + F101.inlet.enth_mol_phase_comp[Vap,hydrogen]*(F101.inlet.flow[Vap,hydrogen]/(F101.inlet.flow[Vap,benzene] + F101.inlet.flow[Vap,toluene] + F101.inlet.flow[Vap,methane] + F101.inlet.flow[Vap,hydrogen])))*(F101.inlet.flow[Vap,benzene] + F101.inlet.flow[Vap,toluene] + F101.inlet.flow[Vap,methane] + F101.inlet.flow[Vap,hydrogen])) + F101.Q - ((F101.outlet.enth_mol_phase_comp[Liq,benzene]*(F101.outlet.flow[Liq,benzene]/(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen])) + F101.outlet.enth_mol_phase_comp[Liq,toluene]*(F101.outlet.flow[Liq,toluene]/(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen])) + F101.outlet.enth_mol_phase_comp[Liq,methane]*(F101.outlet.flow[Liq,methane]/(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen])) + F101.outlet.enth_mol_phase_comp[Liq,hydrogen]*(F101.outlet.flow[Liq,hydrogen]/(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen])))*(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen]) + (F101.outlet.enth_mol_phase_comp[Vap,benzene]*(F101.outlet.flow[Vap,benzene]/(F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen])) + F101.outlet.enth_mol_phase_comp[Vap,toluene]*(F101.outlet.flow[Vap,toluene]/(F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen])) + F101.outlet.enth_mol_phase_comp[Vap,methane]*(F101.outlet.flow[Vap,methane]/(F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen])) + F101.outlet.enth_mol_phase_comp[Vap,hydrogen]*(F101.outlet.flow[Vap,hydrogen]/(F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen])))*(F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen])) :   0.0 :   True
#         rule_inlet_enth_mol_comp_liq : Size=4, Index=F101.Comp, Active=True
#             Key      : Lower : Body                                                                                                                                                                                                                                                                                                                                 : Upper : Active
#              benzene :   0.0 :                     1000.0*F101.inlet.enth_mol_phase_comp[Liq,benzene] - (0.0*(F101.inlet.T**5 - F101.temperature_ref**5) + 0.0*(F101.inlet.T**4 - F101.temperature_ref**4) + 0.216*(F101.inlet.T**3 - F101.temperature_ref**3) - 85.0*(F101.inlet.T**2 - F101.temperature_ref**2) + 129000.0*(F101.inlet.T - F101.temperature_ref)) :   0.0 :   True
#             hydrogen :   0.0 : 1000.0*F101.inlet.enth_mol_phase_comp[Liq,hydrogen] - (0.0*(F101.inlet.T**5 - F101.temperature_ref**5) + 2.5e-09*(F101.inlet.T**4 - F101.temperature_ref**4) + 3.3333333333333334e-09*(F101.inlet.T**3 - F101.temperature_ref**3) + 5e-09*(F101.inlet.T**2 - F101.temperature_ref**2) + 1e-08*(F101.inlet.T - F101.temperature_ref)) :   0.0 :   True
#              methane :   0.0 :  1000.0*F101.inlet.enth_mol_phase_comp[Liq,methane] - (0.0*(F101.inlet.T**5 - F101.temperature_ref**5) + 2.5e-09*(F101.inlet.T**4 - F101.temperature_ref**4) + 3.3333333333333334e-09*(F101.inlet.T**3 - F101.temperature_ref**3) + 5e-09*(F101.inlet.T**2 - F101.temperature_ref**2) + 1e-08*(F101.inlet.T - F101.temperature_ref)) :   0.0 :   True
#              toluene :   0.0 :       1000.0*F101.inlet.enth_mol_phase_comp[Liq,toluene] - (0.0*(F101.inlet.T**5 - F101.temperature_ref**5) + 0.0*(F101.inlet.T**4 - F101.temperature_ref**4) + 0.23166666666666666*(F101.inlet.T**3 - F101.temperature_ref**3) - 76.0*(F101.inlet.T**2 - F101.temperature_ref**2) + 140000.0*(F101.inlet.T - F101.temperature_ref)) :   0.0 :   True
#         rule_inlet_enth_mol_comp_vap : Size=4, Index=F101.Comp, Active=True
#             Key      : Lower : Body                                                                                                                                                                                                                                                                                                                                        : Upper : Active
#              benzene :   0.0 : F101.inlet.enth_mol_phase_comp[Vap,benzene] - (0.0*(F101.inlet.T**5 - F101.temperature_ref**5) + 1.7825e-08*(F101.inlet.T**4 - F101.temperature_ref**4) - 0.00010056666666666667*(F101.inlet.T**3 - F101.temperature_ref**3) + 0.23695*(F101.inlet.T**2 - F101.temperature_ref**2) - 33.92*(F101.inlet.T - F101.temperature_ref) + 33870.0) :   0.0 :   True
#             hydrogen :   0.0 :         F101.inlet.enth_mol_phase_comp[Vap,hydrogen] - (0.0*(F101.inlet.T**5 - F101.temperature_ref**5) + 1.91125e-09*(F101.inlet.T**4 - F101.temperature_ref**4) - 4.603333333333333e-06*(F101.inlet.T**3 - F101.temperature_ref**3) + 0.004637*(F101.inlet.T**2 - F101.temperature_ref**2) + 27.14*(F101.inlet.T - F101.temperature_ref)) :   0.0 :   True
#              methane :   0.0 :                          F101.inlet.enth_mol_phase_comp[Vap,methane] - (0.0*(F101.inlet.T**5 - F101.temperature_ref**5) - 2.83e-09*(F101.inlet.T**4 - F101.temperature_ref**4) + 3.99e-06*(F101.inlet.T**3 - F101.temperature_ref**3) + 0.026065*(F101.inlet.T**2 - F101.temperature_ref**2) + 19.25*(F101.inlet.T - F101.temperature_ref)) :   0.0 :   True
#              toluene :   0.0 : F101.inlet.enth_mol_phase_comp[Vap,toluene] - (0.0*(F101.inlet.T**5 - F101.temperature_ref**5) + 1.22775e-08*(F101.inlet.T**4 - F101.temperature_ref**4) - 9.216666666666667e-05*(F101.inlet.T**3 - F101.temperature_ref**3) + 0.25625*(F101.inlet.T**2 - F101.temperature_ref**2) - 24.35*(F101.inlet.T - F101.temperature_ref) + 38262.0) :   0.0 :   True
#         rule_mass_balance : Size=4, Index=Comp, Active=True
#             Key      : Lower : Body                                                                                                                                : Upper : Active
#              benzene :   0.0 :     (F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Vap,benzene]) - (F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Vap,benzene]) :   0.0 :   True
#             hydrogen :   0.0 : (F101.inlet.flow[Liq,hydrogen] + F101.inlet.flow[Vap,hydrogen]) - (F101.outlet.flow[Liq,hydrogen] + F101.outlet.flow[Vap,hydrogen]) :   0.0 :   True
#              methane :   0.0 :     (F101.inlet.flow[Liq,methane] + F101.inlet.flow[Vap,methane]) - (F101.outlet.flow[Liq,methane] + F101.outlet.flow[Vap,methane]) :   0.0 :   True
#              toluene :   0.0 :     (F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Vap,toluene]) - (F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Vap,toluene]) :   0.0 :   True
#         rule_outlet_enth_mol_comp_liq : Size=4, Index=F101.Comp, Active=True
#             Key      : Lower : Body                                                                                                                                                                                                                                                                                                                                       : Upper : Active
#              benzene :   0.0 :                     1000.0*F101.outlet.enth_mol_phase_comp[Liq,benzene] - (0.0*(F101.outlet.T**5 - F101.temperature_ref**5) + 0.0*(F101.outlet.T**4 - F101.temperature_ref**4) + 0.216*(F101.outlet.T**3 - F101.temperature_ref**3) - 85.0*(F101.outlet.T**2 - F101.temperature_ref**2) + 129000.0*(F101.outlet.T - F101.temperature_ref)) :   0.0 :   True
#             hydrogen :   0.0 : 1000.0*F101.outlet.enth_mol_phase_comp[Liq,hydrogen] - (0.0*(F101.outlet.T**5 - F101.temperature_ref**5) + 2.5e-09*(F101.outlet.T**4 - F101.temperature_ref**4) + 3.3333333333333334e-09*(F101.outlet.T**3 - F101.temperature_ref**3) + 5e-09*(F101.outlet.T**2 - F101.temperature_ref**2) + 1e-08*(F101.outlet.T - F101.temperature_ref)) :   0.0 :   True
#              methane :   0.0 :  1000.0*F101.outlet.enth_mol_phase_comp[Liq,methane] - (0.0*(F101.outlet.T**5 - F101.temperature_ref**5) + 2.5e-09*(F101.outlet.T**4 - F101.temperature_ref**4) + 3.3333333333333334e-09*(F101.outlet.T**3 - F101.temperature_ref**3) + 5e-09*(F101.outlet.T**2 - F101.temperature_ref**2) + 1e-08*(F101.outlet.T - F101.temperature_ref)) :   0.0 :   True
#              toluene :   0.0 :       1000.0*F101.outlet.enth_mol_phase_comp[Liq,toluene] - (0.0*(F101.outlet.T**5 - F101.temperature_ref**5) + 0.0*(F101.outlet.T**4 - F101.temperature_ref**4) + 0.23166666666666666*(F101.outlet.T**3 - F101.temperature_ref**3) - 76.0*(F101.outlet.T**2 - F101.temperature_ref**2) + 140000.0*(F101.outlet.T - F101.temperature_ref)) :   0.0 :   True
#         rule_outlet_enth_mol_comp_vap : Size=4, Index=F101.Comp, Active=True
#             Key      : Lower : Body                                                                                                                                                                                                                                                                                                                                              : Upper : Active
#              benzene :   0.0 : F101.outlet.enth_mol_phase_comp[Vap,benzene] - (0.0*(F101.outlet.T**5 - F101.temperature_ref**5) + 1.7825e-08*(F101.outlet.T**4 - F101.temperature_ref**4) - 0.00010056666666666667*(F101.outlet.T**3 - F101.temperature_ref**3) + 0.23695*(F101.outlet.T**2 - F101.temperature_ref**2) - 33.92*(F101.outlet.T - F101.temperature_ref) + 33870.0) :   0.0 :   True
#             hydrogen :   0.0 :         F101.outlet.enth_mol_phase_comp[Vap,hydrogen] - (0.0*(F101.outlet.T**5 - F101.temperature_ref**5) + 1.91125e-09*(F101.outlet.T**4 - F101.temperature_ref**4) - 4.603333333333333e-06*(F101.outlet.T**3 - F101.temperature_ref**3) + 0.004637*(F101.outlet.T**2 - F101.temperature_ref**2) + 27.14*(F101.outlet.T - F101.temperature_ref)) :   0.0 :   True
#              methane :   0.0 :                          F101.outlet.enth_mol_phase_comp[Vap,methane] - (0.0*(F101.outlet.T**5 - F101.temperature_ref**5) - 2.83e-09*(F101.outlet.T**4 - F101.temperature_ref**4) + 3.99e-06*(F101.outlet.T**3 - F101.temperature_ref**3) + 0.026065*(F101.outlet.T**2 - F101.temperature_ref**2) + 19.25*(F101.outlet.T - F101.temperature_ref)) :   0.0 :   True
#              toluene :   0.0 : F101.outlet.enth_mol_phase_comp[Vap,toluene] - (0.0*(F101.outlet.T**5 - F101.temperature_ref**5) + 1.22775e-08*(F101.outlet.T**4 - F101.temperature_ref**4) - 9.216666666666667e-05*(F101.outlet.T**3 - F101.temperature_ref**3) + 0.25625*(F101.outlet.T**2 - F101.temperature_ref**2) - 24.35*(F101.outlet.T - F101.temperature_ref) + 38262.0) :   0.0 :   True
#
#     2 Block Declarations
#         inlet : Size=1, Index=None, Active=True
#             4 Set Declarations
#                 Comp : Size=1, Index=None, Ordered=Insertion
#                     Key  : Dimen : Domain : Size : Members
#                     None :     1 :    Any :    4 : {'benzene', 'toluene', 'methane', 'hydrogen'}
#                 Phase : Size=1, Index=None, Ordered=Insertion
#                     Key  : Dimen : Domain : Size : Members
#                     None :     1 :    Any :    2 : {'Liq', 'Vap'}
#                 enth_mol_phase_comp_index : Size=1, Index=None, Ordered=True
#                     Key  : Dimen : Domain                           : Size : Members
#                     None :     2 : F101.inlet.Phase*F101.inlet.Comp :    8 : {('Liq', 'benzene'), ('Liq', 'toluene'), ('Liq', 'methane'), ('Liq', 'hydrogen'), ('Vap', 'benzene'), ('Vap', 'toluene'), ('Vap', 'methane'), ('Vap', 'hydrogen')}
#                 flow_index : Size=1, Index=None, Ordered=True
#                     Key  : Dimen : Domain                           : Size : Members
#                     None :     2 : F101.inlet.Phase*F101.inlet.Comp :    8 : {('Liq', 'benzene'), ('Liq', 'toluene'), ('Liq', 'methane'), ('Liq', 'hydrogen'), ('Vap', 'benzene'), ('Vap', 'toluene'), ('Vap', 'methane'), ('Vap', 'hydrogen')}
#
#             4 Var Declarations
#                 P : Size=1, Index=None
#                     Key  : Lower : Value  : Upper         : Fixed : Stale : Domain
#                     None :   100 : 350000 : 10000000000.0 :  True :  True :  Reals
#                 T : Size=1, Index=None
#                     Key  : Lower : Value  : Upper : Fixed : Stale : Domain
#                     None :    25 : 771.85 :  1200 :  True :  True :  Reals
#                 enth_mol_phase_comp : Phase-component molar specific enthalpies
#                     Size=8, Index=F101.inlet.enth_mol_phase_comp_index
#                     Key                 : Lower : Value              : Upper : Fixed : Stale : Domain
#                      ('Liq', 'benzene') :  None : 111623.11861186201 :  None : False : False :  Reals
#                     ('Liq', 'hydrogen') :  None : 0.8689942363537653 :  None : False : False :  Reals
#                      ('Liq', 'methane') :  None : 0.8689942363537653 :  None : False : False :  Reals
#                      ('Liq', 'toluene') :  None : 128184.35390161126 :  None : False : False :  Reals
#                      ('Vap', 'benzene') :  None : 100509.60225694231 :  None : False : False :  Reals
#                     ('Vap', 'hydrogen') :  None : 13875.010151554994 :  None : False : False :  Reals
#                      ('Vap', 'methane') :  None : 23076.919778586198 :  None : False : False :  Reals
#                      ('Vap', 'toluene') :  None : 120932.15720332722 :  None : False : False :  Reals
#                 flow : Size=8, Index=F101.inlet.flow_index
#                     Key                 : Lower : Value    : Upper : Fixed : Stale : Domain
#                      ('Liq', 'benzene') : 1e-12 :    1e-08 :     5 :  True :  True :  Reals
#                     ('Liq', 'hydrogen') : 1e-12 :    1e-08 :     5 :  True :  True :  Reals
#                      ('Liq', 'methane') : 1e-12 :    1e-08 :     5 :  True :  True :  Reals
#                      ('Liq', 'toluene') : 1e-12 :    1e-08 :     5 :  True :  True :  Reals
#                      ('Vap', 'benzene') : 1e-12 :  0.35374 :     5 :  True :  True :  Reals
#                     ('Vap', 'hydrogen') : 1e-12 :  0.32821 :     5 :  True :  True :  Reals
#                      ('Vap', 'methane') : 1e-12 :   1.2721 :     5 :  True :  True :  Reals
#                      ('Vap', 'toluene') : 1e-12 : 0.078129 :     5 :  True :  True :  Reals
#
#             8 Expression Declarations
#                 enth_mol_liq : Size=1, Index=None
#                     Key  : Expression
#                     None : F101.inlet.enth_mol_phase_comp[Liq,benzene]*(F101.inlet.flow[Liq,benzene]/(F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Liq,methane] + F101.inlet.flow[Liq,hydrogen])) + F101.inlet.enth_mol_phase_comp[Liq,toluene]*(F101.inlet.flow[Liq,toluene]/(F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Liq,methane] + F101.inlet.flow[Liq,hydrogen])) + F101.inlet.enth_mol_phase_comp[Liq,methane]*(F101.inlet.flow[Liq,methane]/(F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Liq,methane] + F101.inlet.flow[Liq,hydrogen])) + F101.inlet.enth_mol_phase_comp[Liq,hydrogen]*(F101.inlet.flow[Liq,hydrogen]/(F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Liq,methane] + F101.inlet.flow[Liq,hydrogen]))
#                 enth_mol_vap : Size=1, Index=None
#                     Key  : Expression
#                     None : F101.inlet.enth_mol_phase_comp[Vap,benzene]*(F101.inlet.flow[Vap,benzene]/(F101.inlet.flow[Vap,benzene] + F101.inlet.flow[Vap,toluene] + F101.inlet.flow[Vap,methane] + F101.inlet.flow[Vap,hydrogen])) + F101.inlet.enth_mol_phase_comp[Vap,toluene]*(F101.inlet.flow[Vap,toluene]/(F101.inlet.flow[Vap,benzene] + F101.inlet.flow[Vap,toluene] + F101.inlet.flow[Vap,methane] + F101.inlet.flow[Vap,hydrogen])) + F101.inlet.enth_mol_phase_comp[Vap,methane]*(F101.inlet.flow[Vap,methane]/(F101.inlet.flow[Vap,benzene] + F101.inlet.flow[Vap,toluene] + F101.inlet.flow[Vap,methane] + F101.inlet.flow[Vap,hydrogen])) + F101.inlet.enth_mol_phase_comp[Vap,hydrogen]*(F101.inlet.flow[Vap,hydrogen]/(F101.inlet.flow[Vap,benzene] + F101.inlet.flow[Vap,toluene] + F101.inlet.flow[Vap,methane] + F101.inlet.flow[Vap,hydrogen]))
#                 flow_phase : Size=2, Index=F101.inlet.Phase
#                     Key : Expression
#                     Liq : F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Liq,methane] + F101.inlet.flow[Liq,hydrogen]
#                     Vap : F101.inlet.flow[Vap,benzene] + F101.inlet.flow[Vap,toluene] + F101.inlet.flow[Vap,methane] + F101.inlet.flow[Vap,hydrogen]
#                 total_enth : Size=1, Index=None
#                     Key  : Expression
#                     None : (F101.inlet.enth_mol_phase_comp[Liq,benzene]*(F101.inlet.flow[Liq,benzene]/(F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Liq,methane] + F101.inlet.flow[Liq,hydrogen])) + F101.inlet.enth_mol_phase_comp[Liq,toluene]*(F101.inlet.flow[Liq,toluene]/(F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Liq,methane] + F101.inlet.flow[Liq,hydrogen])) + F101.inlet.enth_mol_phase_comp[Liq,methane]*(F101.inlet.flow[Liq,methane]/(F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Liq,methane] + F101.inlet.flow[Liq,hydrogen])) + F101.inlet.enth_mol_phase_comp[Liq,hydrogen]*(F101.inlet.flow[Liq,hydrogen]/(F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Liq,methane] + F101.inlet.flow[Liq,hydrogen])))*(F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Liq,methane] + F101.inlet.flow[Liq,hydrogen]) + (F101.inlet.enth_mol_phase_comp[Vap,benzene]*(F101.inlet.flow[Vap,benzene]/(F101.inlet.flow[Vap,benzene] + F101.inlet.flow[Vap,toluene] + F101.inlet.flow[Vap,methane] + F101.inlet.flow[Vap,hydrogen])) + F101.inlet.enth_mol_phase_comp[Vap,toluene]*(F101.inlet.flow[Vap,toluene]/(F101.inlet.flow[Vap,benzene] + F101.inlet.flow[Vap,toluene] + F101.inlet.flow[Vap,methane] + F101.inlet.flow[Vap,hydrogen])) + F101.inlet.enth_mol_phase_comp[Vap,methane]*(F101.inlet.flow[Vap,methane]/(F101.inlet.flow[Vap,benzene] + F101.inlet.flow[Vap,toluene] + F101.inlet.flow[Vap,methane] + F101.inlet.flow[Vap,hydrogen])) + F101.inlet.enth_mol_phase_comp[Vap,hydrogen]*(F101.inlet.flow[Vap,hydrogen]/(F101.inlet.flow[Vap,benzene] + F101.inlet.flow[Vap,toluene] + F101.inlet.flow[Vap,methane] + F101.inlet.flow[Vap,hydrogen])))*(F101.inlet.flow[Vap,benzene] + F101.inlet.flow[Vap,toluene] + F101.inlet.flow[Vap,methane] + F101.inlet.flow[Vap,hydrogen])
#                 total_flow : Size=4, Index=F101.inlet.Comp
#                     Key      : Expression
#                      benzene : F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Vap,benzene]
#                     hydrogen : F101.inlet.flow[Liq,hydrogen] + F101.inlet.flow[Vap,hydrogen]
#                      methane : F101.inlet.flow[Liq,methane] + F101.inlet.flow[Vap,methane]
#                      toluene : F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Vap,toluene]
#                 x : Size=4, Index=F101.inlet.Comp
#                     Key      : Expression
#                      benzene : F101.inlet.flow[Liq,benzene]/(F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Liq,methane] + F101.inlet.flow[Liq,hydrogen])
#                     hydrogen : F101.inlet.flow[Liq,hydrogen]/(F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Liq,methane] + F101.inlet.flow[Liq,hydrogen])
#                      methane : F101.inlet.flow[Liq,methane]/(F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Liq,methane] + F101.inlet.flow[Liq,hydrogen])
#                      toluene : F101.inlet.flow[Liq,toluene]/(F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Liq,methane] + F101.inlet.flow[Liq,hydrogen])
#                 y : Size=4, Index=F101.inlet.Comp
#                     Key      : Expression
#                      benzene : F101.inlet.flow[Vap,benzene]/(F101.inlet.flow[Vap,benzene] + F101.inlet.flow[Vap,toluene] + F101.inlet.flow[Vap,methane] + F101.inlet.flow[Vap,hydrogen])
#                     hydrogen : F101.inlet.flow[Vap,hydrogen]/(F101.inlet.flow[Vap,benzene] + F101.inlet.flow[Vap,toluene] + F101.inlet.flow[Vap,methane] + F101.inlet.flow[Vap,hydrogen])
#                      methane : F101.inlet.flow[Vap,methane]/(F101.inlet.flow[Vap,benzene] + F101.inlet.flow[Vap,toluene] + F101.inlet.flow[Vap,methane] + F101.inlet.flow[Vap,hydrogen])
#                      toluene : F101.inlet.flow[Vap,toluene]/(F101.inlet.flow[Vap,benzene] + F101.inlet.flow[Vap,toluene] + F101.inlet.flow[Vap,methane] + F101.inlet.flow[Vap,hydrogen])
#                 z : Size=4, Index=F101.inlet.Comp
#                     Key      : Expression
#                      benzene : (F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Vap,benzene])/(F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Liq,methane] + F101.inlet.flow[Liq,hydrogen] + F101.inlet.flow[Vap,benzene] + F101.inlet.flow[Vap,toluene] + F101.inlet.flow[Vap,methane] + F101.inlet.flow[Vap,hydrogen])
#                     hydrogen : (F101.inlet.flow[Liq,hydrogen] + F101.inlet.flow[Vap,hydrogen])/(F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Liq,methane] + F101.inlet.flow[Liq,hydrogen] + F101.inlet.flow[Vap,benzene] + F101.inlet.flow[Vap,toluene] + F101.inlet.flow[Vap,methane] + F101.inlet.flow[Vap,hydrogen])
#                      methane : (F101.inlet.flow[Liq,methane] + F101.inlet.flow[Vap,methane])/(F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Liq,methane] + F101.inlet.flow[Liq,hydrogen] + F101.inlet.flow[Vap,benzene] + F101.inlet.flow[Vap,toluene] + F101.inlet.flow[Vap,methane] + F101.inlet.flow[Vap,hydrogen])
#                      toluene : (F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Vap,toluene])/(F101.inlet.flow[Liq,benzene] + F101.inlet.flow[Liq,toluene] + F101.inlet.flow[Liq,methane] + F101.inlet.flow[Liq,hydrogen] + F101.inlet.flow[Vap,benzene] + F101.inlet.flow[Vap,toluene] + F101.inlet.flow[Vap,methane] + F101.inlet.flow[Vap,hydrogen])
#
#             16 Declarations: Phase Comp flow_index flow T P total_flow z x y flow_phase enth_mol_phase_comp_index enth_mol_phase_comp enth_mol_liq enth_mol_vap total_enth
#         outlet : Size=1, Index=None, Active=True
#             4 Set Declarations
#                 Comp : Size=1, Index=None, Ordered=Insertion
#                     Key  : Dimen : Domain : Size : Members
#                     None :     1 :    Any :    4 : {'benzene', 'toluene', 'methane', 'hydrogen'}
#                 Phase : Size=1, Index=None, Ordered=Insertion
#                     Key  : Dimen : Domain : Size : Members
#                     None :     1 :    Any :    2 : {'Liq', 'Vap'}
#                 enth_mol_phase_comp_index : Size=1, Index=None, Ordered=True
#                     Key  : Dimen : Domain                             : Size : Members
#                     None :     2 : F101.outlet.Phase*F101.outlet.Comp :    8 : {('Liq', 'benzene'), ('Liq', 'toluene'), ('Liq', 'methane'), ('Liq', 'hydrogen'), ('Vap', 'benzene'), ('Vap', 'toluene'), ('Vap', 'methane'), ('Vap', 'hydrogen')}
#                 flow_index : Size=1, Index=None, Ordered=True
#                     Key  : Dimen : Domain                             : Size : Members
#                     None :     2 : F101.outlet.Phase*F101.outlet.Comp :    8 : {('Liq', 'benzene'), ('Liq', 'toluene'), ('Liq', 'methane'), ('Liq', 'hydrogen'), ('Vap', 'benzene'), ('Vap', 'toluene'), ('Vap', 'methane'), ('Vap', 'hydrogen')}
#
#             4 Var Declarations
#                 P : Size=1, Index=None
#                     Key  : Lower : Value  : Upper         : Fixed : Stale : Domain
#                     None :   100 : 350000 : 10000000000.0 :  True :  True :  Reals
#                 T : Size=1, Index=None
#                     Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                     None :    25 :   325 :  1200 :  True :  True :  Reals
#                 enth_mol_phase_comp : Phase-component molar specific enthalpies
#                     Size=8, Index=F101.outlet.enth_mol_phase_comp_index
#                     Key                 : Lower : Value               : Upper : Fixed : Stale : Domain
#                      ('Liq', 'benzene') :  None :   3731.568946131003 :  None : False : False :  Reals
#                     ('Liq', 'hydrogen') :  None : 0.00816266591641749 :  None : False : False :  Reals
#                      ('Liq', 'methane') :  None : 0.00816266591641749 :  None : False : False :  Reals
#                      ('Liq', 'toluene') :  None :   4300.087777243129 :  None : False : False :  Reals
#                      ('Vap', 'benzene') :  None :   36194.91951427446 :  None : False : False :  Reals
#                     ('Vap', 'hydrogen') :  None :   776.4946624221252 :  None : False : False :  Reals
#                      ('Vap', 'methane') :  None :   974.9805081798853 :  None : False : False :  Reals
#                      ('Vap', 'toluene') :  None :  41214.464795270396 :  None : False : False :  Reals
#                 flow : Size=8, Index=F101.outlet.flow_index
#                     Key                 : Lower : Value                  : Upper : Fixed : Stale : Domain
#                      ('Liq', 'benzene') : 1e-12 :    0.20569381943432377 :     5 : False : False :  Reals
#                     ('Liq', 'hydrogen') : 1e-12 : 0.00010030214098990029 :     5 : False : False :  Reals
#                      ('Liq', 'methane') : 1e-12 :  0.0016167797999828554 :     5 : False : False :  Reals
#                      ('Liq', 'toluene') : 1e-12 :    0.06267808042854957 :     5 : False : False :  Reals
#                      ('Vap', 'benzene') : 1e-12 :    0.14804619056567625 :     5 : False : False :  Reals
#                     ('Vap', 'hydrogen') : 1e-12 :     0.3281097078590101 :     5 : False : False :  Reals
#                      ('Vap', 'methane') : 1e-12 :      1.270483230200017 :     5 : False : False :  Reals
#                      ('Vap', 'toluene') : 1e-12 :    0.01545092957145042 :     5 : False : False :  Reals
#
#             8 Expression Declarations
#                 enth_mol_liq : Size=1, Index=None
#                     Key  : Expression
#                     None : F101.outlet.enth_mol_phase_comp[Liq,benzene]*(F101.outlet.flow[Liq,benzene]/(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen])) + F101.outlet.enth_mol_phase_comp[Liq,toluene]*(F101.outlet.flow[Liq,toluene]/(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen])) + F101.outlet.enth_mol_phase_comp[Liq,methane]*(F101.outlet.flow[Liq,methane]/(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen])) + F101.outlet.enth_mol_phase_comp[Liq,hydrogen]*(F101.outlet.flow[Liq,hydrogen]/(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen]))
#                 enth_mol_vap : Size=1, Index=None
#                     Key  : Expression
#                     None : F101.outlet.enth_mol_phase_comp[Vap,benzene]*(F101.outlet.flow[Vap,benzene]/(F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen])) + F101.outlet.enth_mol_phase_comp[Vap,toluene]*(F101.outlet.flow[Vap,toluene]/(F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen])) + F101.outlet.enth_mol_phase_comp[Vap,methane]*(F101.outlet.flow[Vap,methane]/(F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen])) + F101.outlet.enth_mol_phase_comp[Vap,hydrogen]*(F101.outlet.flow[Vap,hydrogen]/(F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen]))
#                 flow_phase : Size=2, Index=F101.outlet.Phase
#                     Key : Expression
#                     Liq : F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen]
#                     Vap : F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen]
#                 total_enth : Size=1, Index=None
#                     Key  : Expression
#                     None : (F101.outlet.enth_mol_phase_comp[Liq,benzene]*(F101.outlet.flow[Liq,benzene]/(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen])) + F101.outlet.enth_mol_phase_comp[Liq,toluene]*(F101.outlet.flow[Liq,toluene]/(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen])) + F101.outlet.enth_mol_phase_comp[Liq,methane]*(F101.outlet.flow[Liq,methane]/(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen])) + F101.outlet.enth_mol_phase_comp[Liq,hydrogen]*(F101.outlet.flow[Liq,hydrogen]/(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen])))*(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen]) + (F101.outlet.enth_mol_phase_comp[Vap,benzene]*(F101.outlet.flow[Vap,benzene]/(F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen])) + F101.outlet.enth_mol_phase_comp[Vap,toluene]*(F101.outlet.flow[Vap,toluene]/(F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen])) + F101.outlet.enth_mol_phase_comp[Vap,methane]*(F101.outlet.flow[Vap,methane]/(F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen])) + F101.outlet.enth_mol_phase_comp[Vap,hydrogen]*(F101.outlet.flow[Vap,hydrogen]/(F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen])))*(F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen])
#                 total_flow : Size=4, Index=F101.outlet.Comp
#                     Key      : Expression
#                      benzene : F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Vap,benzene]
#                     hydrogen : F101.outlet.flow[Liq,hydrogen] + F101.outlet.flow[Vap,hydrogen]
#                      methane : F101.outlet.flow[Liq,methane] + F101.outlet.flow[Vap,methane]
#                      toluene : F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Vap,toluene]
#                 x : Size=4, Index=F101.outlet.Comp
#                     Key      : Expression
#                      benzene : F101.outlet.flow[Liq,benzene]/(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen])
#                     hydrogen : F101.outlet.flow[Liq,hydrogen]/(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen])
#                      methane : F101.outlet.flow[Liq,methane]/(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen])
#                      toluene : F101.outlet.flow[Liq,toluene]/(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen])
#                 y : Size=4, Index=F101.outlet.Comp
#                     Key      : Expression
#                      benzene : F101.outlet.flow[Vap,benzene]/(F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen])
#                     hydrogen : F101.outlet.flow[Vap,hydrogen]/(F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen])
#                      methane : F101.outlet.flow[Vap,methane]/(F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen])
#                      toluene : F101.outlet.flow[Vap,toluene]/(F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen])
#                 z : Size=4, Index=F101.outlet.Comp
#                     Key      : Expression
#                      benzene : (F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Vap,benzene])/(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen] + F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen])
#                     hydrogen : (F101.outlet.flow[Liq,hydrogen] + F101.outlet.flow[Vap,hydrogen])/(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen] + F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen])
#                      methane : (F101.outlet.flow[Liq,methane] + F101.outlet.flow[Vap,methane])/(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen] + F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen])
#                      toluene : (F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Vap,toluene])/(F101.outlet.flow[Liq,benzene] + F101.outlet.flow[Liq,toluene] + F101.outlet.flow[Liq,methane] + F101.outlet.flow[Liq,hydrogen] + F101.outlet.flow[Vap,benzene] + F101.outlet.flow[Vap,toluene] + F101.outlet.flow[Vap,methane] + F101.outlet.flow[Vap,hydrogen])
#
#             16 Declarations: Phase Comp flow_index flow T P total_flow z x y flow_phase enth_mol_phase_comp_index enth_mol_phase_comp enth_mol_liq enth_mol_vap total_enth
#
#     2 Port Declarations
#         Inlet : Size=1, Index=None
#             Key  : Name : Size : Variable
#             None :    P :    1 :    F101.inlet.P
#                  :    T :    1 :    F101.inlet.T
#                  : flow :    8 : F101.inlet.flow
#         Outlet : Size=1, Index=None
#             Key  : Name : Size : Variable
#             None :    P :    1 :    F101.outlet.P
#                  :    T :    1 :    F101.outlet.T
#                  : flow :    8 : F101.outlet.flow
#
#     39 Declarations: Phase Comp inlet outlet Inlet Outlet pressure_sat_coeff_A pressure_sat_coeff_B pressure_sat_coeff_C pressure_sat eq_phase_equilibrium temperature_bubble temperature_dew _p_sat_dewT _teq _t1 eps_1 eps_2 eq_pressure_sat cp_ig_1_index cp_ig_1 cp_ig_2_index cp_ig_2 cp_ig_3_index cp_ig_3 cp_ig_4_index cp_ig_4 cp_ig_5_index cp_ig_5 pressure_ref temperature_ref dh_vap rule_inlet_enth_mol_comp_liq rule_outlet_enth_mol_comp_liq rule_inlet_enth_mol_comp_vap rule_outlet_enth_mol_comp_vap rule_mass_balance Q rule_energy_balance

# %%
print(degrees_of_freedom(m))
# Out:
# 0

# %%
value((m.F101.outlet.flow['Liq','benzene']/(m.F101.outlet.flow['Liq','benzene'] +
m.F101.outlet.flow['Liq','toluene'] + m.F101.outlet.flow['Liq','methane'] +
m.F101.outlet.flow['Liq','hydrogen']))*m.F101.pressure_sat['benzene'] - \
(m.F101.outlet.flow['Vap','benzene']/(m.F101.outlet.flow['Vap','benzene'] +
m.F101.outlet.flow['Vap','toluene'] + m.F101.outlet.flow['Vap','methane'] +
m.F101.outlet.flow['Vap','hydrogen']))*m.F101.outlet.P)
# Out:
# -1.0913936421275139e-11

# %%
value((m.F101.outlet.flow['Liq','toluene']/(m.F101.outlet.flow['Liq','benzene'] +
m.F101.outlet.flow['Liq','toluene'] + m.F101.outlet.flow['Liq','methane'] + m.F101.outlet.flow['Liq','hydrogen']))* 
      m.F101.pressure_sat['toluene'] - (m.F101.outlet.flow['Vap','toluene']/(m.F101.outlet.flow['Vap','benzene'] +
m.F101.outlet.flow['Vap','toluene'] + m.F101.outlet.flow['Vap','methane'] + m.F101.outlet.flow['Vap','hydrogen']))*m.F101.outlet.P)
# Out:
# -1.3642420526593924e-12

# %%
value((m.F101.outlet.flow['Liq','hydrogen']/(m.F101.outlet.flow['Liq','benzene'] +
m.F101.outlet.flow['Liq','toluene'] + m.F101.outlet.flow['Liq','methane'] + m.F101.outlet.flow['Liq','hydrogen']))* 
      m.F101.pressure_sat['hydrogen'] - (m.F101.outlet.flow['Vap','hydrogen']/(m.F101.outlet.flow['Vap','benzene'] +
m.F101.outlet.flow['Vap','toluene'] + m.F101.outlet.flow['Vap','methane'] + m.F101.outlet.flow['Vap','hydrogen']))*m.F101.outlet.P)
# Out:
# -7.275957614183426e-12

# %%
value((m.F101.outlet.flow['Liq','methane']/(m.F101.outlet.flow['Liq','benzene'] +
m.F101.outlet.flow['Liq','toluene'] + m.F101.outlet.flow['Liq','methane'] + m.F101.outlet.flow['Liq','hydrogen']))* 
      m.F101.pressure_sat['methane'] - (m.F101.outlet.flow['Vap','methane']/(m.F101.outlet.flow['Vap','benzene'] +
m.F101.outlet.flow['Vap','toluene'] + m.F101.outlet.flow['Vap','methane'] + m.F101.outlet.flow['Vap','hydrogen']))*m.F101.outlet.P)
# Out:
# -8.731149137020111e-11

# %%
for constr in m.component_data_objects(Constraint, active=True):
    print(constr.name)
# Out:
# F101.eq_phase_equilibrium[benzene]
# F101.eq_phase_equilibrium[toluene]
# F101.eq_phase_equilibrium[methane]
# F101.eq_phase_equilibrium[hydrogen]
# F101.eq_pressure_sat[benzene]
# F101.eq_pressure_sat[toluene]
# F101.eq_pressure_sat[methane]
# F101.eq_pressure_sat[hydrogen]
# F101.rule_inlet_enth_mol_comp_liq[benzene]
# F101.rule_inlet_enth_mol_comp_liq[toluene]
# F101.rule_inlet_enth_mol_comp_liq[methane]
# F101.rule_inlet_enth_mol_comp_liq[hydrogen]
# F101.rule_outlet_enth_mol_comp_liq[benzene]
# F101.rule_outlet_enth_mol_comp_liq[toluene]
# F101.rule_outlet_enth_mol_comp_liq[methane]
# F101.rule_outlet_enth_mol_comp_liq[hydrogen]
# F101.rule_inlet_enth_mol_comp_vap[benzene]
# F101.rule_inlet_enth_mol_comp_vap[toluene]
# F101.rule_inlet_enth_mol_comp_vap[methane]
# F101.rule_inlet_enth_mol_comp_vap[hydrogen]
# F101.rule_outlet_enth_mol_comp_vap[benzene]
# F101.rule_outlet_enth_mol_comp_vap[toluene]
# F101.rule_outlet_enth_mol_comp_vap[methane]
# F101.rule_outlet_enth_mol_comp_vap[hydrogen]
# F101.rule_mass_balance[benzene]
# F101.rule_mass_balance[toluene]
# F101.rule_mass_balance[methane]
# F101.rule_mass_balance[hydrogen]
# F101.rule_energy_balance

# %%
m.component_data_objects(Constraint, active=True)
# Out:
# <generator object _BlockData.component_data_objects at 0x7fb1e8060270>

# %%
# Iterate over each constraint in the model
for constr in m.component_data_objects(Constraint, active=True):
    # Check the status of the constraint
    status = constr.Body.status
    if status == ConstraintStatus.feasible:
        print(f"Constraint '{constr.name}' is feasible.")
    elif status == ConstraintStatus.infeasible:
        print(f"Constraint '{constr.name}' is infeasible.")
    elif status == ConstraintStatus.unbounded:
        print(f"Constraint '{constr.name}' is unbounded.")
    elif status == ConstraintStatus.deactivated:
        print(f"Constraint '{constr.name}' is deactivated.")
    else:
        print(f"Constraint '{constr.name}' has an unknown status.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 4
#       1 # Iterate over each constraint in the model
#       2 for constr in m.component_data_objects(Constraint, active=True):
#       3     # Check the status of the constraint
# ----> 4     status = constr.Body.status
#       5     if status == ConstraintStatus.feasible:
#       6         print(f"Constraint '{constr.name}' is feasible.")
#
# AttributeError: '_GeneralConstraintData' object has no attribute 'Body'

# %%
m.F101.eq_phase_equilibrium['benzene'] in m.F101.component_data_objects(Constraint, active=True)
# Out:
# True

# %%
results.ConstraintDual[m.F101.eq_phase_equilibrium['benzene']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 ConstraintDual[m.F101.eq_phase_equilibrium['benzene']]
#
# NameError: name 'ConstraintDual' is not defined
