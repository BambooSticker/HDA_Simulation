# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pyomo.environ import *
import pyomo.environ as pyo
from Unit_Model import R101_creater
from idaes.core.util.model_statistics import degrees_of_freedom
from pyomo.util.calc_var_value import calculate_variable_from_constraint
from Method import Initialize

# %%
# Create a concrete model
m = ConcreteModel()

# Define a set for components
m.Phase = Set(initialize = ['Liq','Vap'])
m.Comp = Set(initialize = ['benzene','toluene','methane','hydrogen'])
m.R101 = R101_creater(m)

# %%
# 各组分进料
m.R101.inlet.flow['Liq','benzene'].fix(1e-5)
m.R101.inlet.flow['Liq','toluene'].fix(1e-5)
m.R101.inlet.flow['Liq','methane'].fix(1e-5)
m.R101.inlet.flow['Liq','hydrogen'].fix(1e-5)
m.R101.inlet.flow['Vap','benzene'].fix(0.34138)
m.R101.inlet.flow['Vap','toluene'].fix(0.33308)
m.R101.inlet.flow['Vap','methane'].fix(1.0994)
m.R101.inlet.flow['Vap','hydrogen'].fix(0.50090)

# 温度压力、
m.R101.inlet.P.fix(350000)
m.R101.inlet.T.fix(600)

# %%
Initialize(m.R101)

# %%
m.R101.Q.fix(0)

# %%
print(degrees_of_freedom(m))
# Out:
# 0

# %%
# 模型求解
solver = pyo.SolverFactory('ipopt')
results = solver.solve(m)

# %%
m.R101.pprint()
# Out:
# R101 : Size=1, Index=None, Active=True
#     8 Set Declarations
#         Comp : Size=1, Index=None, Ordered=Insertion
#             Key  : Dimen : Domain : Size : Members
#             None :     1 :    Any :    4 : {'benzene', 'toluene', 'methane', 'hydrogen'}
#         Phase : Size=1, Index=None, Ordered=Insertion
#             Key  : Dimen : Domain : Size : Members
#             None :     1 :    Any :    2 : {'Liq', 'Vap'}
#         cp_ig_1_index : Size=1, Index=None, Ordered=True
#             Key  : Dimen : Domain               : Size : Members
#             None :     2 : R101.Phase*R101.Comp :    8 : {('Liq', 'benzene'), ('Liq', 'toluene'), ('Liq', 'methane'), ('Liq', 'hydrogen'), ('Vap', 'benzene'), ('Vap', 'toluene'), ('Vap', 'methane'), ('Vap', 'hydrogen')}
#         cp_ig_2_index : Size=1, Index=None, Ordered=True
#             Key  : Dimen : Domain               : Size : Members
#             None :     2 : R101.Phase*R101.Comp :    8 : {('Liq', 'benzene'), ('Liq', 'toluene'), ('Liq', 'methane'), ('Liq', 'hydrogen'), ('Vap', 'benzene'), ('Vap', 'toluene'), ('Vap', 'methane'), ('Vap', 'hydrogen')}
#         cp_ig_3_index : Size=1, Index=None, Ordered=True
#             Key  : Dimen : Domain               : Size : Members
#             None :     2 : R101.Phase*R101.Comp :    8 : {('Liq', 'benzene'), ('Liq', 'toluene'), ('Liq', 'methane'), ('Liq', 'hydrogen'), ('Vap', 'benzene'), ('Vap', 'toluene'), ('Vap', 'methane'), ('Vap', 'hydrogen')}
#         cp_ig_4_index : Size=1, Index=None, Ordered=True
#             Key  : Dimen : Domain               : Size : Members
#             None :     2 : R101.Phase*R101.Comp :    8 : {('Liq', 'benzene'), ('Liq', 'toluene'), ('Liq', 'methane'), ('Liq', 'hydrogen'), ('Vap', 'benzene'), ('Vap', 'toluene'), ('Vap', 'methane'), ('Vap', 'hydrogen')}
#         cp_ig_5_index : Size=1, Index=None, Ordered=True
#             Key  : Dimen : Domain               : Size : Members
#             None :     2 : R101.Phase*R101.Comp :    8 : {('Liq', 'benzene'), ('Liq', 'toluene'), ('Liq', 'methane'), ('Liq', 'hydrogen'), ('Vap', 'benzene'), ('Vap', 'toluene'), ('Vap', 'methane'), ('Vap', 'hydrogen')}
#         rate_reaction_idx : Size=1, Index=None, Ordered=Insertion
#             Key  : Dimen : Domain : Size : Members
#             None :     1 :    Any :    1 : {'R1',}
#
#     16 Param Declarations
#         cp_ig_1 : Parameter 1 to compute Cp_comp
#             Size=8, Index=R101.cp_ig_1_index, Domain=Any, Default=None, Mutable=False
#             Key                 : Value
#              ('Liq', 'benzene') : 129000.0
#             ('Liq', 'hydrogen') :    1e-08
#              ('Liq', 'methane') :    1e-08
#              ('Liq', 'toluene') : 140000.0
#              ('Vap', 'benzene') :   -33.92
#             ('Vap', 'hydrogen') :    27.14
#              ('Vap', 'methane') :    19.25
#              ('Vap', 'toluene') :   -24.35
#         cp_ig_2 : Parameter 2 to compute Cp_comp
#             Size=8, Index=R101.cp_ig_2_index, Domain=Any, Default=None, Mutable=False
#             Key                 : Value
#              ('Liq', 'benzene') :   -170.0
#             ('Liq', 'hydrogen') :    1e-08
#              ('Liq', 'methane') :    1e-08
#              ('Liq', 'toluene') :   -152.0
#              ('Vap', 'benzene') :   0.4739
#             ('Vap', 'hydrogen') : 0.009274
#              ('Vap', 'methane') :  0.05213
#              ('Vap', 'toluene') :   0.5125
#         cp_ig_3 : Parameter 3 to compute Cp_comp
#             Size=8, Index=R101.cp_ig_3_index, Domain=Any, Default=None, Mutable=False
#             Key                 : Value
#              ('Liq', 'benzene') :      0.648
#             ('Liq', 'hydrogen') :      1e-08
#              ('Liq', 'methane') :      1e-08
#              ('Liq', 'toluene') :      0.695
#              ('Vap', 'benzene') : -0.0003017
#             ('Vap', 'hydrogen') : -1.381e-05
#              ('Vap', 'methane') :  1.197e-05
#              ('Vap', 'toluene') : -0.0002765
#         cp_ig_4 : Parameter 4 to compute Cp_comp
#             Size=8, Index=R101.cp_ig_4_index, Domain=Any, Default=None, Mutable=False
#             Key                 : Value
#              ('Liq', 'benzene') :          0
#             ('Liq', 'hydrogen') :      1e-08
#              ('Liq', 'methane') :      1e-08
#              ('Liq', 'toluene') :          0
#              ('Vap', 'benzene') :   7.13e-08
#             ('Vap', 'hydrogen') :  7.645e-09
#              ('Vap', 'methane') : -1.132e-08
#              ('Vap', 'toluene') :  4.911e-08
#         cp_ig_5 : Parameter 5 to compute Cp_comp
#             Size=8, Index=R101.cp_ig_5_index, Domain=Any, Default=None, Mutable=False
#             Key                 : Value
#              ('Liq', 'benzene') :     0
#             ('Liq', 'hydrogen') :     0
#              ('Liq', 'methane') :     0
#              ('Liq', 'toluene') :     0
#              ('Vap', 'benzene') :     0
#             ('Vap', 'hydrogen') :     0
#              ('Vap', 'methane') :     0
#              ('Vap', 'toluene') :     0
#         dh_rxn : Heat of reaction
#             Size=1, Index=R101.rate_reaction_idx, Domain=Any, Default=None, Mutable=False
#             Key : Value
#              R1 : 108000.0
#         dh_vap : heat of vaporization
#             Size=4, Index=R101.Comp, Domain=Any, Default=None, Mutable=False
#             Key      : Value
#              benzene : 33870.0
#             hydrogen :       0
#              methane :       0
#              toluene : 38262.0
#         eps_1 : Smoothing parameter for T1
#             Size=1, Index=None, Domain=Any, Default=0.01, Mutable=True
#             Key  : Value
#             None :  0.01
#         eps_2 : Smoothing parameter for Teq
#             Size=1, Index=None, Domain=Any, Default=0.0005, Mutable=True
#             Key  : Value
#             None : 0.0005
#         extent_of_reaction : Size=1, Index=None, Domain=Any, Default=0.75, Mutable=False
#             Key : Value
#         pressure_ref : Reference pressure
#             Size=1, Index=None, Domain=Any, Default=101325, Mutable=True
#             Key : Value
#         pressure_sat_coeff_A : Parameter A to compute saturated pressure
#             Size=4, Index=R101.Comp, Domain=Any, Default=None, Mutable=False
#             Key      : Value
#              benzene : 4.202
#             hydrogen : 3.543
#              methane :  3.99
#              toluene : 4.216
#         pressure_sat_coeff_B : Parameter B to compute saturated pressure
#             Size=4, Index=R101.Comp, Domain=Any, Default=None, Mutable=False
#             Key      : Value
#              benzene :  1322
#             hydrogen :  99.4
#              methane : 443.0
#              toluene :  1435
#         pressure_sat_coeff_C : Parameter C to compute saturated pressure
#             Size=4, Index=R101.Comp, Domain=Any, Default=None, Mutable=False
#             Key      : Value
#              benzene : -38.56
#             hydrogen :  7.726
#              methane :  -0.49
#              toluene : -43.33
#         temperature_bubble : Bubble point temperature
#             Size=1, Index=None, Domain=Any, Default=None, Mutable=False
#             Key  : Value
#             None :    50
#         temperature_ref : Reference temperature
#             Size=1, Index=None, Domain=Any, Default=298.15, Mutable=True
#             Key  : Value
#             None : 298.15
#
#     5 Var Declarations
#         Q : Size=1, Index=None
#             Key  : Lower : Value : Upper : Fixed : Stale : Domain
#             None :  None :     0 :  None :  True :  True :  Reals
#         _t1 : Intermediate temperature for calculating Teq
#             Size=1, Index=None
#             Key  : Lower : Value             : Upper : Fixed : Stale : Domain
#             None :  None : 298.1500001007455 :  None :  True :  True :  Reals
#         _teq : Temperature for calculating phase equilibrium
#             Size=1, Index=None
#             Key  : Lower : Value             : Upper : Fixed : Stale : Domain
#             None :  None : 298.1500000990812 :  None :  True :  True :  Reals
#         pressure_sat : Vapor pressure
#             Size=4, Index=R101.Comp
#             Key      : Lower : Value              : Upper         : Fixed : Stale : Domain
#              benzene :   100 : 12863.344657410797 : 10000000000.0 : False : False :  Reals
#             hydrogen :   100 :  165208242.9272666 : 10000000000.0 : False : False :  Reals
#              methane :   100 : 31748615.202087104 : 10000000000.0 : False : False :  Reals
#              toluene :   100 :  3842.146297553164 : 10000000000.0 : False : False :  Reals
#         temperature_dew : Dew point temperature
#             Size=1, Index=None
#             Key  : Lower : Value             : Upper : Fixed : Stale : Domain
#             None :   100 : 335.7019055390753 :   500 :  True :  True :  Reals
#
#     1 Expression Declarations
#         _p_sat_dewT : Size=4, Index=R101.Comp
#             Key      : Expression
#              benzene : 100000.0*10**(4.202 - 1322/(R101.temperature_dew - 38.56))
#             hydrogen : 100000.0*10**(3.543 - 99.4/(R101.temperature_dew + 7.726))
#              methane : 100000.0*10**(3.99 - 443.0/(R101.temperature_dew - 0.49))
#              toluene : 100000.0*10**(4.216 - 1435/(R101.temperature_dew - 43.33))
#
#     7 Constraint Declarations
#         eq_pressure_sat : Size=4, Index=R101.Comp, Active=True
#             Key      : Lower   : Body                                                                   : Upper   : Active
#              benzene : -1322.0 :  (log10(1e-05*R101.pressure_sat[benzene]) - 4.202)*(R101._teq - 38.56) : -1322.0 :   True
#             hydrogen :   -99.4 : (log10(1e-05*R101.pressure_sat[hydrogen]) - 3.543)*(R101._teq + 7.726) :   -99.4 :   True
#              methane :  -443.0 :    (log10(1e-05*R101.pressure_sat[methane]) - 3.99)*(R101._teq - 0.49) :  -443.0 :   True
#              toluene : -1435.0 :  (log10(1e-05*R101.pressure_sat[toluene]) - 4.216)*(R101._teq - 43.33) : -1435.0 :   True
#         rule_energy_balance : Size=1, Index=None, Active=True
#             Key  : Lower : Body                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          : Upper : Active
#             None :   0.0 : ((R101.inlet.enth_mol_phase_comp[Liq,benzene]*(R101.inlet.flow[Liq,benzene]/(R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Liq,methane] + R101.inlet.flow[Liq,hydrogen])) + R101.inlet.enth_mol_phase_comp[Liq,toluene]*(R101.inlet.flow[Liq,toluene]/(R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Liq,methane] + R101.inlet.flow[Liq,hydrogen])) + R101.inlet.enth_mol_phase_comp[Liq,methane]*(R101.inlet.flow[Liq,methane]/(R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Liq,methane] + R101.inlet.flow[Liq,hydrogen])) + R101.inlet.enth_mol_phase_comp[Liq,hydrogen]*(R101.inlet.flow[Liq,hydrogen]/(R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Liq,methane] + R101.inlet.flow[Liq,hydrogen])))*(R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Liq,methane] + R101.inlet.flow[Liq,hydrogen]) + (R101.inlet.enth_mol_phase_comp[Vap,benzene]*(R101.inlet.flow[Vap,benzene]/(R101.inlet.flow[Vap,benzene] + R101.inlet.flow[Vap,toluene] + R101.inlet.flow[Vap,methane] + R101.inlet.flow[Vap,hydrogen])) + R101.inlet.enth_mol_phase_comp[Vap,toluene]*(R101.inlet.flow[Vap,toluene]/(R101.inlet.flow[Vap,benzene] + R101.inlet.flow[Vap,toluene] + R101.inlet.flow[Vap,methane] + R101.inlet.flow[Vap,hydrogen])) + R101.inlet.enth_mol_phase_comp[Vap,methane]*(R101.inlet.flow[Vap,methane]/(R101.inlet.flow[Vap,benzene] + R101.inlet.flow[Vap,toluene] + R101.inlet.flow[Vap,methane] + R101.inlet.flow[Vap,hydrogen])) + R101.inlet.enth_mol_phase_comp[Vap,hydrogen]*(R101.inlet.flow[Vap,hydrogen]/(R101.inlet.flow[Vap,benzene] + R101.inlet.flow[Vap,toluene] + R101.inlet.flow[Vap,methane] + R101.inlet.flow[Vap,hydrogen])))*(R101.inlet.flow[Vap,benzene] + R101.inlet.flow[Vap,toluene] + R101.inlet.flow[Vap,methane] + R101.inlet.flow[Vap,hydrogen])) + R101.Q + 81000.0*R101.inlet.flow[Vap,toluene] - ((R101.outlet.enth_mol_phase_comp[Liq,benzene]*(R101.outlet.flow[Liq,benzene]/(R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Liq,methane] + R101.outlet.flow[Liq,hydrogen])) + R101.outlet.enth_mol_phase_comp[Liq,toluene]*(R101.outlet.flow[Liq,toluene]/(R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Liq,methane] + R101.outlet.flow[Liq,hydrogen])) + R101.outlet.enth_mol_phase_comp[Liq,methane]*(R101.outlet.flow[Liq,methane]/(R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Liq,methane] + R101.outlet.flow[Liq,hydrogen])) + R101.outlet.enth_mol_phase_comp[Liq,hydrogen]*(R101.outlet.flow[Liq,hydrogen]/(R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Liq,methane] + R101.outlet.flow[Liq,hydrogen])))*(R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Liq,methane] + R101.outlet.flow[Liq,hydrogen]) + (R101.outlet.enth_mol_phase_comp[Vap,benzene]*(R101.outlet.flow[Vap,benzene]/(R101.outlet.flow[Vap,benzene] + R101.outlet.flow[Vap,toluene] + R101.outlet.flow[Vap,methane] + R101.outlet.flow[Vap,hydrogen])) + R101.outlet.enth_mol_phase_comp[Vap,toluene]*(R101.outlet.flow[Vap,toluene]/(R101.outlet.flow[Vap,benzene] + R101.outlet.flow[Vap,toluene] + R101.outlet.flow[Vap,methane] + R101.outlet.flow[Vap,hydrogen])) + R101.outlet.enth_mol_phase_comp[Vap,methane]*(R101.outlet.flow[Vap,methane]/(R101.outlet.flow[Vap,benzene] + R101.outlet.flow[Vap,toluene] + R101.outlet.flow[Vap,methane] + R101.outlet.flow[Vap,hydrogen])) + R101.outlet.enth_mol_phase_comp[Vap,hydrogen]*(R101.outlet.flow[Vap,hydrogen]/(R101.outlet.flow[Vap,benzene] + R101.outlet.flow[Vap,toluene] + R101.outlet.flow[Vap,methane] + R101.outlet.flow[Vap,hydrogen])))*(R101.outlet.flow[Vap,benzene] + R101.outlet.flow[Vap,toluene] + R101.outlet.flow[Vap,methane] + R101.outlet.flow[Vap,hydrogen])) :   0.0 :   True
#         rule_inlet_enth_mol_comp_liq : Size=4, Index=R101.Comp, Active=True
#             Key      : Lower : Body                                                                                                                                                                                                                                                                                                                                 : Upper : Active
#              benzene :   0.0 :                     1000.0*R101.inlet.enth_mol_phase_comp[Liq,benzene] - (0.0*(R101.inlet.T**5 - R101.temperature_ref**5) + 0.0*(R101.inlet.T**4 - R101.temperature_ref**4) + 0.216*(R101.inlet.T**3 - R101.temperature_ref**3) - 85.0*(R101.inlet.T**2 - R101.temperature_ref**2) + 129000.0*(R101.inlet.T - R101.temperature_ref)) :   0.0 :   True
#             hydrogen :   0.0 : 1000.0*R101.inlet.enth_mol_phase_comp[Liq,hydrogen] - (0.0*(R101.inlet.T**5 - R101.temperature_ref**5) + 2.5e-09*(R101.inlet.T**4 - R101.temperature_ref**4) + 3.3333333333333334e-09*(R101.inlet.T**3 - R101.temperature_ref**3) + 5e-09*(R101.inlet.T**2 - R101.temperature_ref**2) + 1e-08*(R101.inlet.T - R101.temperature_ref)) :   0.0 :   True
#              methane :   0.0 :  1000.0*R101.inlet.enth_mol_phase_comp[Liq,methane] - (0.0*(R101.inlet.T**5 - R101.temperature_ref**5) + 2.5e-09*(R101.inlet.T**4 - R101.temperature_ref**4) + 3.3333333333333334e-09*(R101.inlet.T**3 - R101.temperature_ref**3) + 5e-09*(R101.inlet.T**2 - R101.temperature_ref**2) + 1e-08*(R101.inlet.T - R101.temperature_ref)) :   0.0 :   True
#              toluene :   0.0 :       1000.0*R101.inlet.enth_mol_phase_comp[Liq,toluene] - (0.0*(R101.inlet.T**5 - R101.temperature_ref**5) + 0.0*(R101.inlet.T**4 - R101.temperature_ref**4) + 0.23166666666666666*(R101.inlet.T**3 - R101.temperature_ref**3) - 76.0*(R101.inlet.T**2 - R101.temperature_ref**2) + 140000.0*(R101.inlet.T - R101.temperature_ref)) :   0.0 :   True
#         rule_inlet_enth_mol_comp_vap : Size=4, Index=R101.Comp, Active=True
#             Key      : Lower : Body                                                                                                                                                                                                                                                                                                                                        : Upper : Active
#              benzene :   0.0 : R101.inlet.enth_mol_phase_comp[Vap,benzene] - (0.0*(R101.inlet.T**5 - R101.temperature_ref**5) + 1.7825e-08*(R101.inlet.T**4 - R101.temperature_ref**4) - 0.00010056666666666667*(R101.inlet.T**3 - R101.temperature_ref**3) + 0.23695*(R101.inlet.T**2 - R101.temperature_ref**2) - 33.92*(R101.inlet.T - R101.temperature_ref) + 33870.0) :   0.0 :   True
#             hydrogen :   0.0 :         R101.inlet.enth_mol_phase_comp[Vap,hydrogen] - (0.0*(R101.inlet.T**5 - R101.temperature_ref**5) + 1.91125e-09*(R101.inlet.T**4 - R101.temperature_ref**4) - 4.603333333333333e-06*(R101.inlet.T**3 - R101.temperature_ref**3) + 0.004637*(R101.inlet.T**2 - R101.temperature_ref**2) + 27.14*(R101.inlet.T - R101.temperature_ref)) :   0.0 :   True
#              methane :   0.0 :                          R101.inlet.enth_mol_phase_comp[Vap,methane] - (0.0*(R101.inlet.T**5 - R101.temperature_ref**5) - 2.83e-09*(R101.inlet.T**4 - R101.temperature_ref**4) + 3.99e-06*(R101.inlet.T**3 - R101.temperature_ref**3) + 0.026065*(R101.inlet.T**2 - R101.temperature_ref**2) + 19.25*(R101.inlet.T - R101.temperature_ref)) :   0.0 :   True
#              toluene :   0.0 : R101.inlet.enth_mol_phase_comp[Vap,toluene] - (0.0*(R101.inlet.T**5 - R101.temperature_ref**5) + 1.22775e-08*(R101.inlet.T**4 - R101.temperature_ref**4) - 9.216666666666667e-05*(R101.inlet.T**3 - R101.temperature_ref**3) + 0.25625*(R101.inlet.T**2 - R101.temperature_ref**2) - 24.35*(R101.inlet.T - R101.temperature_ref) + 38262.0) :   0.0 :   True
#         rule_momentum_balance : Size=1, Index=None, Active=True
#             Key  : Lower : Body                         : Upper : Active
#             None :   0.0 : R101.outlet.P - R101.inlet.P :   0.0 :   True
#         rule_outlet_enth_mol_comp_liq : Size=4, Index=R101.Comp, Active=True
#             Key      : Lower : Body                                                                                                                                                                                                                                                                                                                                       : Upper : Active
#              benzene :   0.0 :                     1000.0*R101.outlet.enth_mol_phase_comp[Liq,benzene] - (0.0*(R101.outlet.T**5 - R101.temperature_ref**5) + 0.0*(R101.outlet.T**4 - R101.temperature_ref**4) + 0.216*(R101.outlet.T**3 - R101.temperature_ref**3) - 85.0*(R101.outlet.T**2 - R101.temperature_ref**2) + 129000.0*(R101.outlet.T - R101.temperature_ref)) :   0.0 :   True
#             hydrogen :   0.0 : 1000.0*R101.outlet.enth_mol_phase_comp[Liq,hydrogen] - (0.0*(R101.outlet.T**5 - R101.temperature_ref**5) + 2.5e-09*(R101.outlet.T**4 - R101.temperature_ref**4) + 3.3333333333333334e-09*(R101.outlet.T**3 - R101.temperature_ref**3) + 5e-09*(R101.outlet.T**2 - R101.temperature_ref**2) + 1e-08*(R101.outlet.T - R101.temperature_ref)) :   0.0 :   True
#              methane :   0.0 :  1000.0*R101.outlet.enth_mol_phase_comp[Liq,methane] - (0.0*(R101.outlet.T**5 - R101.temperature_ref**5) + 2.5e-09*(R101.outlet.T**4 - R101.temperature_ref**4) + 3.3333333333333334e-09*(R101.outlet.T**3 - R101.temperature_ref**3) + 5e-09*(R101.outlet.T**2 - R101.temperature_ref**2) + 1e-08*(R101.outlet.T - R101.temperature_ref)) :   0.0 :   True
#              toluene :   0.0 :       1000.0*R101.outlet.enth_mol_phase_comp[Liq,toluene] - (0.0*(R101.outlet.T**5 - R101.temperature_ref**5) + 0.0*(R101.outlet.T**4 - R101.temperature_ref**4) + 0.23166666666666666*(R101.outlet.T**3 - R101.temperature_ref**3) - 76.0*(R101.outlet.T**2 - R101.temperature_ref**2) + 140000.0*(R101.outlet.T - R101.temperature_ref)) :   0.0 :   True
#         rule_outlet_enth_mol_comp_vap : Size=4, Index=R101.Comp, Active=True
#             Key      : Lower : Body                                                                                                                                                                                                                                                                                                                                              : Upper : Active
#              benzene :   0.0 : R101.outlet.enth_mol_phase_comp[Vap,benzene] - (0.0*(R101.outlet.T**5 - R101.temperature_ref**5) + 1.7825e-08*(R101.outlet.T**4 - R101.temperature_ref**4) - 0.00010056666666666667*(R101.outlet.T**3 - R101.temperature_ref**3) + 0.23695*(R101.outlet.T**2 - R101.temperature_ref**2) - 33.92*(R101.outlet.T - R101.temperature_ref) + 33870.0) :   0.0 :   True
#             hydrogen :   0.0 :         R101.outlet.enth_mol_phase_comp[Vap,hydrogen] - (0.0*(R101.outlet.T**5 - R101.temperature_ref**5) + 1.91125e-09*(R101.outlet.T**4 - R101.temperature_ref**4) - 4.603333333333333e-06*(R101.outlet.T**3 - R101.temperature_ref**3) + 0.004637*(R101.outlet.T**2 - R101.temperature_ref**2) + 27.14*(R101.outlet.T - R101.temperature_ref)) :   0.0 :   True
#              methane :   0.0 :                          R101.outlet.enth_mol_phase_comp[Vap,methane] - (0.0*(R101.outlet.T**5 - R101.temperature_ref**5) - 2.83e-09*(R101.outlet.T**4 - R101.temperature_ref**4) + 3.99e-06*(R101.outlet.T**3 - R101.temperature_ref**3) + 0.026065*(R101.outlet.T**2 - R101.temperature_ref**2) + 19.25*(R101.outlet.T - R101.temperature_ref)) :   0.0 :   True
#              toluene :   0.0 : R101.outlet.enth_mol_phase_comp[Vap,toluene] - (0.0*(R101.outlet.T**5 - R101.temperature_ref**5) + 1.22775e-08*(R101.outlet.T**4 - R101.temperature_ref**4) - 9.216666666666667e-05*(R101.outlet.T**3 - R101.temperature_ref**3) + 0.25625*(R101.outlet.T**2 - R101.temperature_ref**2) - 24.35*(R101.outlet.T - R101.temperature_ref) + 38262.0) :   0.0 :   True
#
#     2 Block Declarations
#         inlet : Size=1, Index=None, Active=True
#             4 Set Declarations
#                 Comp : Size=1, Index=None, Ordered=Insertion
#                     Key  : Dimen : Domain : Size : Members
#                     None :     1 :    Any :    4 : {'benzene', 'toluene', 'methane', 'hydrogen'}
#                 Phase : Size=1, Index=None, Ordered=Insertion
#                     Key  : Dimen : Domain : Size : Members
#                     None :     1 :    Any :    2 : {'Liq', 'Vap'}
#                 enth_mol_phase_comp_index : Size=1, Index=None, Ordered=True
#                     Key  : Dimen : Domain                           : Size : Members
#                     None :     2 : R101.inlet.Phase*R101.inlet.Comp :    8 : {('Liq', 'benzene'), ('Liq', 'toluene'), ('Liq', 'methane'), ('Liq', 'hydrogen'), ('Vap', 'benzene'), ('Vap', 'toluene'), ('Vap', 'methane'), ('Vap', 'hydrogen')}
#                 flow_index : Size=1, Index=None, Ordered=True
#                     Key  : Dimen : Domain                           : Size : Members
#                     None :     2 : R101.inlet.Phase*R101.inlet.Comp :    8 : {('Liq', 'benzene'), ('Liq', 'toluene'), ('Liq', 'methane'), ('Liq', 'hydrogen'), ('Vap', 'benzene'), ('Vap', 'toluene'), ('Vap', 'methane'), ('Vap', 'hydrogen')}
#
#             4 Var Declarations
#                 P : Size=1, Index=None
#                     Key  : Lower : Value  : Upper         : Fixed : Stale : Domain
#                     None :   100 : 350000 : 10000000000.0 :  True :  True :  Reals
#                 T : Size=1, Index=None
#                     Key  : Lower : Value : Upper : Fixed : Stale : Domain
#                     None :    25 :   600 :  1200 :  True :  True :  Reals
#                 enth_mol_phase_comp : Phase-component molar specific enthalpies
#                     Size=8, Index=R101.inlet.enth_mol_phase_comp_index
#                     Key                 : Lower : Value              : Upper : Fixed : Stale : Domain
#                      ('Liq', 'benzene') :  None :    56825.818946131 :  None : False : False :  Reals
#                     ('Liq', 'hydrogen') :  None : 0.3048779118955841 :  None : False : False :  Reals
#                      ('Liq', 'methane') :  None : 0.3048779118955841 :  None : False : False :  Reals
#                      ('Liq', 'toluene') :  None :  65554.90548557646 :  None : False : False :  Reals
#                      ('Vap', 'benzene') :  None :   70982.1937493005 :  None : False : False :  Reals
#                     ('Vap', 'hydrogen') :  None :  8809.610210110926 :  None : False : False :  Reals
#                      ('Vap', 'methane') :  None : 13288.690957398636 :  None : False : False :  Reals
#                      ('Vap', 'toluene') :  None :  84411.90574416363 :  None : False : False :  Reals
#                 flow : Size=8, Index=R101.inlet.flow_index
#                     Key                 : Lower : Value   : Upper : Fixed : Stale : Domain
#                      ('Liq', 'benzene') : 1e-12 :   1e-05 :     5 :  True :  True :  Reals
#                     ('Liq', 'hydrogen') : 1e-12 :   1e-05 :     5 :  True :  True :  Reals
#                      ('Liq', 'methane') : 1e-12 :   1e-05 :     5 :  True :  True :  Reals
#                      ('Liq', 'toluene') : 1e-12 :   1e-05 :     5 :  True :  True :  Reals
#                      ('Vap', 'benzene') : 1e-12 : 0.34138 :     5 :  True :  True :  Reals
#                     ('Vap', 'hydrogen') : 1e-12 :  0.5009 :     5 :  True :  True :  Reals
#                      ('Vap', 'methane') : 1e-12 :  1.0994 :     5 :  True :  True :  Reals
#                      ('Vap', 'toluene') : 1e-12 : 0.33308 :     5 :  True :  True :  Reals
#
#             8 Expression Declarations
#                 enth_mol_liq : Size=1, Index=None
#                     Key  : Expression
#                     None : R101.inlet.enth_mol_phase_comp[Liq,benzene]*(R101.inlet.flow[Liq,benzene]/(R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Liq,methane] + R101.inlet.flow[Liq,hydrogen])) + R101.inlet.enth_mol_phase_comp[Liq,toluene]*(R101.inlet.flow[Liq,toluene]/(R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Liq,methane] + R101.inlet.flow[Liq,hydrogen])) + R101.inlet.enth_mol_phase_comp[Liq,methane]*(R101.inlet.flow[Liq,methane]/(R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Liq,methane] + R101.inlet.flow[Liq,hydrogen])) + R101.inlet.enth_mol_phase_comp[Liq,hydrogen]*(R101.inlet.flow[Liq,hydrogen]/(R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Liq,methane] + R101.inlet.flow[Liq,hydrogen]))
#                 enth_mol_vap : Size=1, Index=None
#                     Key  : Expression
#                     None : R101.inlet.enth_mol_phase_comp[Vap,benzene]*(R101.inlet.flow[Vap,benzene]/(R101.inlet.flow[Vap,benzene] + R101.inlet.flow[Vap,toluene] + R101.inlet.flow[Vap,methane] + R101.inlet.flow[Vap,hydrogen])) + R101.inlet.enth_mol_phase_comp[Vap,toluene]*(R101.inlet.flow[Vap,toluene]/(R101.inlet.flow[Vap,benzene] + R101.inlet.flow[Vap,toluene] + R101.inlet.flow[Vap,methane] + R101.inlet.flow[Vap,hydrogen])) + R101.inlet.enth_mol_phase_comp[Vap,methane]*(R101.inlet.flow[Vap,methane]/(R101.inlet.flow[Vap,benzene] + R101.inlet.flow[Vap,toluene] + R101.inlet.flow[Vap,methane] + R101.inlet.flow[Vap,hydrogen])) + R101.inlet.enth_mol_phase_comp[Vap,hydrogen]*(R101.inlet.flow[Vap,hydrogen]/(R101.inlet.flow[Vap,benzene] + R101.inlet.flow[Vap,toluene] + R101.inlet.flow[Vap,methane] + R101.inlet.flow[Vap,hydrogen]))
#                 flow_phase : Size=2, Index=R101.inlet.Phase
#                     Key : Expression
#                     Liq : R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Liq,methane] + R101.inlet.flow[Liq,hydrogen]
#                     Vap : R101.inlet.flow[Vap,benzene] + R101.inlet.flow[Vap,toluene] + R101.inlet.flow[Vap,methane] + R101.inlet.flow[Vap,hydrogen]
#                 total_enth : Size=1, Index=None
#                     Key  : Expression
#                     None : (R101.inlet.enth_mol_phase_comp[Liq,benzene]*(R101.inlet.flow[Liq,benzene]/(R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Liq,methane] + R101.inlet.flow[Liq,hydrogen])) + R101.inlet.enth_mol_phase_comp[Liq,toluene]*(R101.inlet.flow[Liq,toluene]/(R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Liq,methane] + R101.inlet.flow[Liq,hydrogen])) + R101.inlet.enth_mol_phase_comp[Liq,methane]*(R101.inlet.flow[Liq,methane]/(R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Liq,methane] + R101.inlet.flow[Liq,hydrogen])) + R101.inlet.enth_mol_phase_comp[Liq,hydrogen]*(R101.inlet.flow[Liq,hydrogen]/(R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Liq,methane] + R101.inlet.flow[Liq,hydrogen])))*(R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Liq,methane] + R101.inlet.flow[Liq,hydrogen]) + (R101.inlet.enth_mol_phase_comp[Vap,benzene]*(R101.inlet.flow[Vap,benzene]/(R101.inlet.flow[Vap,benzene] + R101.inlet.flow[Vap,toluene] + R101.inlet.flow[Vap,methane] + R101.inlet.flow[Vap,hydrogen])) + R101.inlet.enth_mol_phase_comp[Vap,toluene]*(R101.inlet.flow[Vap,toluene]/(R101.inlet.flow[Vap,benzene] + R101.inlet.flow[Vap,toluene] + R101.inlet.flow[Vap,methane] + R101.inlet.flow[Vap,hydrogen])) + R101.inlet.enth_mol_phase_comp[Vap,methane]*(R101.inlet.flow[Vap,methane]/(R101.inlet.flow[Vap,benzene] + R101.inlet.flow[Vap,toluene] + R101.inlet.flow[Vap,methane] + R101.inlet.flow[Vap,hydrogen])) + R101.inlet.enth_mol_phase_comp[Vap,hydrogen]*(R101.inlet.flow[Vap,hydrogen]/(R101.inlet.flow[Vap,benzene] + R101.inlet.flow[Vap,toluene] + R101.inlet.flow[Vap,methane] + R101.inlet.flow[Vap,hydrogen])))*(R101.inlet.flow[Vap,benzene] + R101.inlet.flow[Vap,toluene] + R101.inlet.flow[Vap,methane] + R101.inlet.flow[Vap,hydrogen])
#                 total_flow : Size=4, Index=R101.inlet.Comp
#                     Key      : Expression
#                      benzene : R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Vap,benzene]
#                     hydrogen : R101.inlet.flow[Liq,hydrogen] + R101.inlet.flow[Vap,hydrogen]
#                      methane : R101.inlet.flow[Liq,methane] + R101.inlet.flow[Vap,methane]
#                      toluene : R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Vap,toluene]
#                 x : Size=4, Index=R101.inlet.Comp
#                     Key      : Expression
#                      benzene : R101.inlet.flow[Liq,benzene]/(R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Liq,methane] + R101.inlet.flow[Liq,hydrogen])
#                     hydrogen : R101.inlet.flow[Liq,hydrogen]/(R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Liq,methane] + R101.inlet.flow[Liq,hydrogen])
#                      methane : R101.inlet.flow[Liq,methane]/(R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Liq,methane] + R101.inlet.flow[Liq,hydrogen])
#                      toluene : R101.inlet.flow[Liq,toluene]/(R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Liq,methane] + R101.inlet.flow[Liq,hydrogen])
#                 y : Size=4, Index=R101.inlet.Comp
#                     Key      : Expression
#                      benzene : R101.inlet.flow[Vap,benzene]/(R101.inlet.flow[Vap,benzene] + R101.inlet.flow[Vap,toluene] + R101.inlet.flow[Vap,methane] + R101.inlet.flow[Vap,hydrogen])
#                     hydrogen : R101.inlet.flow[Vap,hydrogen]/(R101.inlet.flow[Vap,benzene] + R101.inlet.flow[Vap,toluene] + R101.inlet.flow[Vap,methane] + R101.inlet.flow[Vap,hydrogen])
#                      methane : R101.inlet.flow[Vap,methane]/(R101.inlet.flow[Vap,benzene] + R101.inlet.flow[Vap,toluene] + R101.inlet.flow[Vap,methane] + R101.inlet.flow[Vap,hydrogen])
#                      toluene : R101.inlet.flow[Vap,toluene]/(R101.inlet.flow[Vap,benzene] + R101.inlet.flow[Vap,toluene] + R101.inlet.flow[Vap,methane] + R101.inlet.flow[Vap,hydrogen])
#                 z : Size=4, Index=R101.inlet.Comp
#                     Key      : Expression
#                      benzene : (R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Vap,benzene])/(R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Liq,methane] + R101.inlet.flow[Liq,hydrogen] + R101.inlet.flow[Vap,benzene] + R101.inlet.flow[Vap,toluene] + R101.inlet.flow[Vap,methane] + R101.inlet.flow[Vap,hydrogen])
#                     hydrogen : (R101.inlet.flow[Liq,hydrogen] + R101.inlet.flow[Vap,hydrogen])/(R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Liq,methane] + R101.inlet.flow[Liq,hydrogen] + R101.inlet.flow[Vap,benzene] + R101.inlet.flow[Vap,toluene] + R101.inlet.flow[Vap,methane] + R101.inlet.flow[Vap,hydrogen])
#                      methane : (R101.inlet.flow[Liq,methane] + R101.inlet.flow[Vap,methane])/(R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Liq,methane] + R101.inlet.flow[Liq,hydrogen] + R101.inlet.flow[Vap,benzene] + R101.inlet.flow[Vap,toluene] + R101.inlet.flow[Vap,methane] + R101.inlet.flow[Vap,hydrogen])
#                      toluene : (R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Vap,toluene])/(R101.inlet.flow[Liq,benzene] + R101.inlet.flow[Liq,toluene] + R101.inlet.flow[Liq,methane] + R101.inlet.flow[Liq,hydrogen] + R101.inlet.flow[Vap,benzene] + R101.inlet.flow[Vap,toluene] + R101.inlet.flow[Vap,methane] + R101.inlet.flow[Vap,hydrogen])
#
#             16 Declarations: Phase Comp flow_index flow T P total_flow z x y flow_phase enth_mol_phase_comp_index enth_mol_phase_comp enth_mol_liq enth_mol_vap total_enth
#         outlet : Size=1, Index=None, Active=True
#             4 Set Declarations
#                 Comp : Size=1, Index=None, Ordered=Insertion
#                     Key  : Dimen : Domain : Size : Members
#                     None :     1 :    Any :    4 : {'benzene', 'toluene', 'methane', 'hydrogen'}
#                 Phase : Size=1, Index=None, Ordered=Insertion
#                     Key  : Dimen : Domain : Size : Members
#                     None :     1 :    Any :    2 : {'Liq', 'Vap'}
#                 enth_mol_phase_comp_index : Size=1, Index=None, Ordered=True
#                     Key  : Dimen : Domain                             : Size : Members
#                     None :     2 : R101.outlet.Phase*R101.outlet.Comp :    8 : {('Liq', 'benzene'), ('Liq', 'toluene'), ('Liq', 'methane'), ('Liq', 'hydrogen'), ('Vap', 'benzene'), ('Vap', 'toluene'), ('Vap', 'methane'), ('Vap', 'hydrogen')}
#                 flow_index : Size=1, Index=None, Ordered=True
#                     Key  : Dimen : Domain                             : Size : Members
#                     None :     2 : R101.outlet.Phase*R101.outlet.Comp :    8 : {('Liq', 'benzene'), ('Liq', 'toluene'), ('Liq', 'methane'), ('Liq', 'hydrogen'), ('Vap', 'benzene'), ('Vap', 'toluene'), ('Vap', 'methane'), ('Vap', 'hydrogen')}
#
#             4 Var Declarations
#                 P : Size=1, Index=None
#                     Key  : Lower : Value    : Upper         : Fixed : Stale : Domain
#                     None :   100 : 350000.0 : 10000000000.0 : False : False :  Reals
#                 T : Size=1, Index=None
#                     Key  : Lower : Value             : Upper : Fixed : Stale : Domain
#                     None :    25 : 745.2375741983969 :  1200 : False : False :  Reals
#                 enth_mol_phase_comp : Phase-component molar specific enthalpies
#                     Size=8, Index=R101.outlet.enth_mol_phase_comp_index
#                     Key                 : Lower : Value              : Upper : Fixed : Stale : Domain
#                      ('Liq', 'benzene') :  None : 101698.34273197802 :  None : False : False :  Reals
#                     ('Liq', 'hydrogen') :  None : 0.7526532220673042 :  None : False : False :  Reals
#                      ('Liq', 'methane') :  None : 0.7526532220673042 :  None : False : False :  Reals
#                      ('Liq', 'toluene') :  None :  116883.7201358706 :  None : False : False :  Reals
#                      ('Vap', 'benzene') :  None :   95637.6567610028 :  None : False : False :  Reals
#                     ('Vap', 'hydrogen') :  None : 13088.199231114155 :  None : False : False :  Reals
#                      ('Vap', 'methane') :  None :  21460.51357592687 :  None : False : False :  Reals
#                      ('Vap', 'toluene') :  None :   114898.230702738 :  None : False : False :  Reals
#                 flow : Size=8, Index=R101.outlet.flow_index
#                     Key                 : Lower : Value                  : Upper : Fixed : Stale : Domain
#                      ('Liq', 'benzene') : 1e-12 : 1.0000000000010001e-05 :     5 :  True :  True :  Reals
#                     ('Liq', 'hydrogen') : 1e-12 : 1.0000000000010001e-05 :     5 :  True :  True :  Reals
#                      ('Liq', 'methane') : 1e-12 : 1.0000000000010001e-05 :     5 :  True :  True :  Reals
#                      ('Liq', 'toluene') : 1e-12 : 1.0000000000010001e-05 :     5 :  True :  True :  Reals
#                      ('Vap', 'benzene') : 1e-12 :                0.59119 :     5 :  True :  True :  Reals
#                     ('Vap', 'hydrogen') : 1e-12 :    0.25109000000000004 :     5 :  True :  True :  Reals
#                      ('Vap', 'methane') : 1e-12 :     1.3492099999999998 :     5 :  True :  True :  Reals
#                      ('Vap', 'toluene') : 1e-12 :    0.08327000000000001 :     5 :  True :  True :  Reals
#
#             8 Expression Declarations
#                 enth_mol_liq : Size=1, Index=None
#                     Key  : Expression
#                     None : R101.outlet.enth_mol_phase_comp[Liq,benzene]*(R101.outlet.flow[Liq,benzene]/(R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Liq,methane] + R101.outlet.flow[Liq,hydrogen])) + R101.outlet.enth_mol_phase_comp[Liq,toluene]*(R101.outlet.flow[Liq,toluene]/(R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Liq,methane] + R101.outlet.flow[Liq,hydrogen])) + R101.outlet.enth_mol_phase_comp[Liq,methane]*(R101.outlet.flow[Liq,methane]/(R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Liq,methane] + R101.outlet.flow[Liq,hydrogen])) + R101.outlet.enth_mol_phase_comp[Liq,hydrogen]*(R101.outlet.flow[Liq,hydrogen]/(R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Liq,methane] + R101.outlet.flow[Liq,hydrogen]))
#                 enth_mol_vap : Size=1, Index=None
#                     Key  : Expression
#                     None : R101.outlet.enth_mol_phase_comp[Vap,benzene]*(R101.outlet.flow[Vap,benzene]/(R101.outlet.flow[Vap,benzene] + R101.outlet.flow[Vap,toluene] + R101.outlet.flow[Vap,methane] + R101.outlet.flow[Vap,hydrogen])) + R101.outlet.enth_mol_phase_comp[Vap,toluene]*(R101.outlet.flow[Vap,toluene]/(R101.outlet.flow[Vap,benzene] + R101.outlet.flow[Vap,toluene] + R101.outlet.flow[Vap,methane] + R101.outlet.flow[Vap,hydrogen])) + R101.outlet.enth_mol_phase_comp[Vap,methane]*(R101.outlet.flow[Vap,methane]/(R101.outlet.flow[Vap,benzene] + R101.outlet.flow[Vap,toluene] + R101.outlet.flow[Vap,methane] + R101.outlet.flow[Vap,hydrogen])) + R101.outlet.enth_mol_phase_comp[Vap,hydrogen]*(R101.outlet.flow[Vap,hydrogen]/(R101.outlet.flow[Vap,benzene] + R101.outlet.flow[Vap,toluene] + R101.outlet.flow[Vap,methane] + R101.outlet.flow[Vap,hydrogen]))
#                 flow_phase : Size=2, Index=R101.outlet.Phase
#                     Key : Expression
#                     Liq : R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Liq,methane] + R101.outlet.flow[Liq,hydrogen]
#                     Vap : R101.outlet.flow[Vap,benzene] + R101.outlet.flow[Vap,toluene] + R101.outlet.flow[Vap,methane] + R101.outlet.flow[Vap,hydrogen]
#                 total_enth : Size=1, Index=None
#                     Key  : Expression
#                     None : (R101.outlet.enth_mol_phase_comp[Liq,benzene]*(R101.outlet.flow[Liq,benzene]/(R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Liq,methane] + R101.outlet.flow[Liq,hydrogen])) + R101.outlet.enth_mol_phase_comp[Liq,toluene]*(R101.outlet.flow[Liq,toluene]/(R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Liq,methane] + R101.outlet.flow[Liq,hydrogen])) + R101.outlet.enth_mol_phase_comp[Liq,methane]*(R101.outlet.flow[Liq,methane]/(R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Liq,methane] + R101.outlet.flow[Liq,hydrogen])) + R101.outlet.enth_mol_phase_comp[Liq,hydrogen]*(R101.outlet.flow[Liq,hydrogen]/(R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Liq,methane] + R101.outlet.flow[Liq,hydrogen])))*(R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Liq,methane] + R101.outlet.flow[Liq,hydrogen]) + (R101.outlet.enth_mol_phase_comp[Vap,benzene]*(R101.outlet.flow[Vap,benzene]/(R101.outlet.flow[Vap,benzene] + R101.outlet.flow[Vap,toluene] + R101.outlet.flow[Vap,methane] + R101.outlet.flow[Vap,hydrogen])) + R101.outlet.enth_mol_phase_comp[Vap,toluene]*(R101.outlet.flow[Vap,toluene]/(R101.outlet.flow[Vap,benzene] + R101.outlet.flow[Vap,toluene] + R101.outlet.flow[Vap,methane] + R101.outlet.flow[Vap,hydrogen])) + R101.outlet.enth_mol_phase_comp[Vap,methane]*(R101.outlet.flow[Vap,methane]/(R101.outlet.flow[Vap,benzene] + R101.outlet.flow[Vap,toluene] + R101.outlet.flow[Vap,methane] + R101.outlet.flow[Vap,hydrogen])) + R101.outlet.enth_mol_phase_comp[Vap,hydrogen]*(R101.outlet.flow[Vap,hydrogen]/(R101.outlet.flow[Vap,benzene] + R101.outlet.flow[Vap,toluene] + R101.outlet.flow[Vap,methane] + R101.outlet.flow[Vap,hydrogen])))*(R101.outlet.flow[Vap,benzene] + R101.outlet.flow[Vap,toluene] + R101.outlet.flow[Vap,methane] + R101.outlet.flow[Vap,hydrogen])
#                 total_flow : Size=4, Index=R101.outlet.Comp
#                     Key      : Expression
#                      benzene : R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Vap,benzene]
#                     hydrogen : R101.outlet.flow[Liq,hydrogen] + R101.outlet.flow[Vap,hydrogen]
#                      methane : R101.outlet.flow[Liq,methane] + R101.outlet.flow[Vap,methane]
#                      toluene : R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Vap,toluene]
#                 x : Size=4, Index=R101.outlet.Comp
#                     Key      : Expression
#                      benzene : R101.outlet.flow[Liq,benzene]/(R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Liq,methane] + R101.outlet.flow[Liq,hydrogen])
#                     hydrogen : R101.outlet.flow[Liq,hydrogen]/(R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Liq,methane] + R101.outlet.flow[Liq,hydrogen])
#                      methane : R101.outlet.flow[Liq,methane]/(R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Liq,methane] + R101.outlet.flow[Liq,hydrogen])
#                      toluene : R101.outlet.flow[Liq,toluene]/(R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Liq,methane] + R101.outlet.flow[Liq,hydrogen])
#                 y : Size=4, Index=R101.outlet.Comp
#                     Key      : Expression
#                      benzene : R101.outlet.flow[Vap,benzene]/(R101.outlet.flow[Vap,benzene] + R101.outlet.flow[Vap,toluene] + R101.outlet.flow[Vap,methane] + R101.outlet.flow[Vap,hydrogen])
#                     hydrogen : R101.outlet.flow[Vap,hydrogen]/(R101.outlet.flow[Vap,benzene] + R101.outlet.flow[Vap,toluene] + R101.outlet.flow[Vap,methane] + R101.outlet.flow[Vap,hydrogen])
#                      methane : R101.outlet.flow[Vap,methane]/(R101.outlet.flow[Vap,benzene] + R101.outlet.flow[Vap,toluene] + R101.outlet.flow[Vap,methane] + R101.outlet.flow[Vap,hydrogen])
#                      toluene : R101.outlet.flow[Vap,toluene]/(R101.outlet.flow[Vap,benzene] + R101.outlet.flow[Vap,toluene] + R101.outlet.flow[Vap,methane] + R101.outlet.flow[Vap,hydrogen])
#                 z : Size=4, Index=R101.outlet.Comp
#                     Key      : Expression
#                      benzene : (R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Vap,benzene])/(R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Liq,methane] + R101.outlet.flow[Liq,hydrogen] + R101.outlet.flow[Vap,benzene] + R101.outlet.flow[Vap,toluene] + R101.outlet.flow[Vap,methane] + R101.outlet.flow[Vap,hydrogen])
#                     hydrogen : (R101.outlet.flow[Liq,hydrogen] + R101.outlet.flow[Vap,hydrogen])/(R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Liq,methane] + R101.outlet.flow[Liq,hydrogen] + R101.outlet.flow[Vap,benzene] + R101.outlet.flow[Vap,toluene] + R101.outlet.flow[Vap,methane] + R101.outlet.flow[Vap,hydrogen])
#                      methane : (R101.outlet.flow[Liq,methane] + R101.outlet.flow[Vap,methane])/(R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Liq,methane] + R101.outlet.flow[Liq,hydrogen] + R101.outlet.flow[Vap,benzene] + R101.outlet.flow[Vap,toluene] + R101.outlet.flow[Vap,methane] + R101.outlet.flow[Vap,hydrogen])
#                      toluene : (R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Vap,toluene])/(R101.outlet.flow[Liq,benzene] + R101.outlet.flow[Liq,toluene] + R101.outlet.flow[Liq,methane] + R101.outlet.flow[Liq,hydrogen] + R101.outlet.flow[Vap,benzene] + R101.outlet.flow[Vap,toluene] + R101.outlet.flow[Vap,methane] + R101.outlet.flow[Vap,hydrogen])
#
#             16 Declarations: Phase Comp flow_index flow T P total_flow z x y flow_phase enth_mol_phase_comp_index enth_mol_phase_comp enth_mol_liq enth_mol_vap total_enth
#
#     2 Port Declarations
#         Inlet : Size=1, Index=None
#             Key  : Name : Size : Variable
#             None :    P :    1 :    R101.inlet.P
#                  :    T :    1 :    R101.inlet.T
#                  : flow :    8 : R101.inlet.flow
#         Outlet : Size=1, Index=None
#             Key  : Name : Size : Variable
#             None :    P :    1 :    R101.outlet.P
#                  :    T :    1 :    R101.outlet.T
#                  : flow :    8 : R101.outlet.flow
#
#     41 Declarations: Phase Comp inlet outlet Inlet Outlet pressure_sat_coeff_A pressure_sat_coeff_B pressure_sat_coeff_C pressure_sat temperature_bubble temperature_dew _p_sat_dewT _teq _t1 eps_1 eps_2 eq_pressure_sat cp_ig_1_index cp_ig_1 cp_ig_2_index cp_ig_2 cp_ig_3_index cp_ig_3 cp_ig_4_index cp_ig_4 cp_ig_5_index cp_ig_5 pressure_ref temperature_ref dh_vap rule_inlet_enth_mol_comp_liq rule_outlet_enth_mol_comp_liq rule_inlet_enth_mol_comp_vap rule_outlet_enth_mol_comp_vap rate_reaction_idx extent_of_reaction rule_momentum_balance Q dh_rxn rule_energy_balance
