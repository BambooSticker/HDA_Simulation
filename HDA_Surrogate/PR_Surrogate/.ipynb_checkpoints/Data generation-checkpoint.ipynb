# %%
import pytest
import numpy as np
import pandas as pd
from idaes.core import FlowsheetBlock
from idaes.models.properties.cubic_eos.cubic_prop_pack import cubic_roots_available
import BT_PR
from idaes.core.util.exceptions import InitializationError

from pyomo.environ import (
    check_optimal_termination,
    ConcreteModel,
    Constraint,
    Objective,
    value,
)
from pyomo.util.check_units import assert_units_consistent

from idaes.models.properties.tests.test_harness import PropertyTestHarness
from idaes.core.solvers import get_solver
# Set module level pyest marker
pytestmark = pytest.mark.cubic_root
prop_available = cubic_roots_available()


# -----------------------------------------------------------------------------
# Get default solver for testing
solver = get_solver()
solver.options['print_level'] = 0

# %%
# temperature, pressure
temperature = np.linspace(350, 400, 50)
pressure = np.linspace(140000, 160000, 10)
frac_In_benzene = np.linspace(0.5, 0.9, 10)
dict = {
    "Temperature": [],
    "Pressure": [],
    "frac_In_benzene": []
}
#data = pd.DataFrame()

# %%
for i in range(len(temperature)):
    for j in range(len(pressure)):
        for k in range(len(frac_In_benzene)):
            dict["Temperature"].append(temperature[i])
            dict["Pressure"].append(pressure[j])
            dict["frac_In_benzene"].append(frac_In_benzene[k])

# %%
columns=["Temperature","Pressure","frac_In_benzene","mole_frac_liq_benzene",
         "mole_frac_vap_benzene"
        ]
data = pd.DataFrame(dict,columns = columns)

# %%
data.head()
# Out:
#    Temperature  Pressure  frac_In_benzene mole_frac_liq_benzene  \
# 0        350.0  140000.0         0.650000                   NaN
# 1        350.0  140000.0         0.672222                   NaN
# 2        350.0  140000.0         0.694444                   NaN
# 3        350.0  140000.0         0.716667                   NaN
# 4        350.0  140000.0         0.738889                   NaN
#
#   mole_frac_vap_benzene
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
def ceos_gen(data):
    
    '''
    input: #5000
        i: index
        Temperature: [350K, 400K] #50
        Pressure: [140000Pa, 160000Pa] #10
        mole_frac_comp(benzene):[0.5, 0.9] #10
    output: 
        mole_frac_liq_benzene
        mole_frac_vap_benzene
        
    '''

    dict_out = {
        "mole_frac_liq_benzene": [],
        "mole_frac_vap_benzene": []
    }

    m = ConcreteModel()
        
    m.fs = FlowsheetBlock(dynamic=False)
    
    m.fs.props = BT_PR.BTParameterBlock(valid_phase=("Vap", "Liq"))
    
    m.fs.state = m.fs.props.build_state_block([0], defined_state=True)
    
    m.fs.state[0].flow_mol.fix(100)
    for i in data.index:
        
        m.fs.state[0].mole_frac_comp["benzene"].fix(data["Fraction_B"][i])
        m.fs.state[0].mole_frac_comp["toluene"].fix(1-data["Fraction_B"][i])
        m.fs.state[0].temperature.fix(data["Temperature"][i])
        m.fs.state[0].pressure.fix(data["Pressure"][i])
        
        # Trigger build of enthalpy and entropy
        m.fs.state[0].enth_mol_phase
        m.fs.state[0].entr_mol_phase
        
        m.fs.state.initialize()
        
        solver.solve(m)
        
        dict_out["mole_frac_liq_benzene"].append(value(m.fs.state[0].mole_frac_phase_comp["Liq", "benzene"]))
        dict_out["mole_frac_vap_benzene"].append(value(m.fs.state[0].mole_frac_phase_comp["Vap", "benzene"]))

    return dict_out

# %% [markdown]
# # 生成测试集 1000个

# %%
# temperature, pressure
temperature = np.random.uniform(350, 400, 1000)
pressure = np.random.uniform(140000, 160000, 1000)
frac_In_benzene = np.linspace(0.5, 0.9, 1000)
dict = {
    "Temperature": [],
    "Pressure": [],
    "Fraction_B": []
}

for i in range(1000):
    dict["Temperature"].append(temperature[i])
    dict["Pressure"].append(pressure[i])
    dict["Fraction_B"].append(frac_In_benzene[i])
test_data = pd.DataFrame(dict)

# %%
dict_out = ceos_gen(test_data)
# Out:
# 2024-04-18 15:56:49 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 15
[INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:48 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:48 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:48 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:49 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:49 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:50 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:50 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:50 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:51 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:51 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:52 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:52 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:52 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:53 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:53 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:54 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:54 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:55 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:55 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:55 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:56 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:56 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:57 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:57 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:57 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:58 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:58 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:59 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:02:59 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:00 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:00 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:00 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:01 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:01 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:02 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:02 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:02 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:03 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:03 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:04 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:04 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:04 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:05 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:05 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:06 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:06 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:06 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:07 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:07 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:08 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:08 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:09 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:09 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:09 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:10 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:10 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:11 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:11 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:11 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:12 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:12 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:13 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:13 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:13 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:14 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:14 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:15 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:15 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:16 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:16 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:16 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:17 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:17 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:18 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:18 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:18 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:19 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:19 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:20 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:20 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:20 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:21 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:21 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:22 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:22 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:23 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:23 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:23 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:24 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:24 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:25 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:25 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:25 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:26 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:26 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:27 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:27 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:28 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:28 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:28 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:29 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:29 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:30 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:30 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:30 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:31 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:31 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:32 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:32 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:33 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:33 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:33 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:34 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:34 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:35 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:35 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:35 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:36 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:36 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:37 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:37 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:37 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:38 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:38 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:39 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:39 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:40 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:40 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:40 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:41 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:41 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:42 [INFO] idaes.init.fs.state: Initialization complete.
# 2024-04-18 16:03:42 [INFO] idaes.init.fs.state: Initialization complete.

# %%
test_data["Liq_B"] = dict_out["mole_frac_liq_benzene"]
test_data["Vap_B"] = dict_out["mole_frac_vap_benzene"]
test_data
# Out:
#      Temperature       Pressure  Fraction_B     Liq_B     Vap_B
# 0     356.311458  151046.758968    0.500000  0.500000  0.693615
# 1     377.313885  157420.973455    0.500400  0.500400  0.692707
# 2     367.758804  151406.399720    0.500801  0.500801  0.694239
# 3     361.978915  146842.471554    0.501201  0.501201  0.695512
# 4     393.572231  141005.840995    0.501602  0.309794  0.501602
# ..           ...            ...         ...       ...       ...
# 995   375.732166  158624.292517    0.898398  0.793400  0.898398
# 996   357.538720  154424.556033    0.898799  0.898799  0.953864
# 997   386.864342  154268.312520    0.899199  0.794175  0.899199
# 998   373.688284  143236.855211    0.899600  0.793165  0.899600
# 999   368.904302  147809.795995    0.900000  0.881271  0.945559
#
# [1000 rows x 5 columns]

# %%
test_data.to_csv("test_data_1000.csv")

# %%
data.to_csv("BT_PR_data.csv",index=False)

# %%
m = ConcreteModel()

m.fs = FlowsheetBlock(dynamic=False)

m.fs.props = BT_PR.BTParameterBlock(valid_phase=("Vap", "Liq"))

m.fs.state = m.fs.props.build_state_block([0], defined_state=True)

m.fs.state[0].flow_mol.fix(100)
m.fs.state[0].mole_frac_comp["benzene"].fix(0.5)
m.fs.state[0].mole_frac_comp["toluene"].fix(0.5)
m.fs.state[0].temperature.fix(380)
m.fs.state[0].pressure.fix(1.5e5)

# Trigger build of enthalpy and entropy
m.fs.state[0].enth_mol_phase
m.fs.state[0].entr_mol_phase

m.fs.state.initialize()

solver.solve(m)
# Out:
# 2024-04-20 20:37:37 [INFO] idaes.init.fs.state: Initialization complete.
# {'Problem': [{'Lower bound': -inf, 'Upper bound': inf, 'Number of objectives': 1, 'Number of constraints': 18, 'Number of variables': 18, 'Sense': 'unknown'}], 'Solver': [{'Status': 'ok', 'Message': 'Ipopt 3.13.2\\x3a Optimal Solution Found', 'Termination condition': 'optimal', 'Id': 0, 'Error rc': 0, 'Time': 0.0389559268951416}], 'Solution': [OrderedDict([('number of solutions', 0), ('number of solutions displayed', 0)])]}
